# %% [markdown]
# ## Kaggle competition:<br>
# https://www.kaggle.com/competitions/playground-series-s4e11

# %% [markdown]
# ## import libraries and load data

# %%
## import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")

## load the training data
train = pd.read_csv("train.csv")
## load the test data
test = pd.read_csv("test.csv")

# %% [markdown]
# ## Data Preprocessing

# %%
print(train.shape)
print(test.shape)
print(train["Depression"].value_counts())
print(train.columns)
# Out:
# (140700, 20)
# (93800, 19)
# Depression
# 0    115133
# 1     25567
# Name: count, dtype: int64
# Index(['id', 'Name', 'Gender', 'Age', 'City',
#        'Working Professional or Student', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %% [markdown]
# ### check for outliers

# %%
print(train.head())
## check possible values for possible categorical columns
categories = [
    "Gender",
    "City",
    "Working Professional or Student",
    "Profession",
    "Academic Pressure",
    "Work Pressure",
    "Study Satisfaction",
    "Job Satisfaction",
    "Sleep Duration",
    "Dietary Habits",
    "Degree",
    "Have you ever had suicidal thoughts ?",
    "Work/Study Hours",
    "Financial Stress",
    "Family History of Mental Illness",
]
outlier_tests = pd.DataFrame()
for category in categories:
    test_unique = pd.Series(test[category].unique())  # Convert to Series
    train_unique = pd.Series(train[category].unique())  # Convert to Series
    if len(test_unique[~test_unique.isin(train_unique)]) > 0:
        print(category)
        outlier_test = test[
            test[category].isin(test_unique[~test_unique.isin(train_unique)])
        ]
        print(len(outlier_test))
        print(outlier_test)
        outlier_tests = pd.concat([outlier_tests, outlier_test])
        print("\n")
# Get unique rows of the DataFrame
outlier_tests = outlier_tests.drop_duplicates()
print(outlier_tests)
print(outlier_tests.shape)
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0       Varanasi            Working Professional
# 2   2    Yuvraj    Male  33.0  Visakhapatnam                         Student
# 3   3    Yuvraj    Male  22.0         Mumbai            Working Professional
# 4   4      Rhea  Female  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# 1                 NaN               3.0  Less than 5 hours      Unhealthy
# 2                 2.0               NaN          5-6 hours        Healthy
# 3                 NaN               1.0  Less than 5 hours       Moderate
# 4                 NaN               1.0          5-6 hours      Unhealthy
#
#     Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0      BHM                                    No               1.0
# 1      LLB                                   Yes               7.0
# 2  B.Pharm                                   Yes               3.0
# 3      BBA                                   Yes              10.0
# 4      BBA                                   Yes               9.0
#
#    Financial Stress Family History of Mental Illness  Depression
# 0               2.0                               No           0
# 1               3.0                               No           1
# 2               1.0                               No           1
# 3               1.0                              Yes           1
# 4               4.0                              Yes           0
# City
# 30
#            id      Name  Gender   Age               City  \
# 943    141643     Kunal    Male  21.0             Malyan
# 3010   143710    Advait    Male  20.0  Less than 5 hours
# 3297   143997    Aadhya  Female  23.0              Aditi
# 12520  153220    Khushi  Female  24.0             Mhopal
# 13689  154389       Ila  Female  47.0               Avni
# 17405  158105      Mahi  Female  50.0                Ira
# 23873  164573    Vihaan    Male  41.0             Lawyer
# 24433  165133     Naina  Female  57.0              Thani
# 25799  166499  Abhishek    Male  25.0            Hrithik
# 29614  170314     Aryan    Male  57.0            Hrithik
# 34733  175433    Harsha    Male  53.0              Unaly
# 41144  181844     Rupal  Female  30.0          Is Kanpur
# 41702  182402    Raunak    Male  58.0            Golkata
# 45311  186011      Sara  Female  40.0               Sara
# 47608  188308      Riya  Female  56.0             Saurav
# 47676  188376    Siddhi  Female  32.0             Vikram
# 51233  191933     Kavya  Female  55.0           Siddhesh
# 53512  194212     Darsh    Male  48.0             Vaikot
# 59792  200492   Aanchal  Female  27.0              Leela
# 70403  211103     Vidhi  Female  56.0            Chemist
# 72657  213357    Aniket    Male  46.0    San Vasai-Virar
# 79092  219792     Rohan    Male  37.0         More Delhi
# 79574  220274       Jai    Male  31.0           Siddhesh
# 80241  220941      Arya    Male  24.0             Vikram
# 87983  228683   Pratham    Male  59.0            Pratham
# 88497  229197    Vedant    Male  23.0            Abhinav
# 89086  229786    Jhanvi  Female  47.0            Rolkata
# 89094  229794  Aaradhya  Female  35.0           Siddhesh
# 90766  231466   Tanisha  Female  24.0             Ghopal
# 92459  233159     Vidhi  Female  57.0              No.12
#
#       Working Professional or Student           Profession  Academic Pressure  \
# 943                           Student                  NaN                5.0
# 3010                          Student                  NaN                1.0
# 3297             Working Professional           Consultant                NaN
# 12520                         Student                  NaN                3.0
# 13689            Working Professional         Entrepreneur                NaN
# 17405            Working Professional              Chemist                NaN
# 23873            Working Professional               Lawyer                NaN
# 24433            Working Professional           Researcher                NaN
# 25799            Working Professional    Marketing Manager                NaN
# 29614            Working Professional              Teacher                NaN
# 34733            Working Professional  Mechanical Engineer                NaN
# 41144                         Student                  NaN                4.0
# 41702            Working Professional           HR Manager                NaN
# 45311            Working Professional       Content Writer                NaN
# 47608            Working Professional            Architect                NaN
# 47676                         Student                  NaN                4.0
# 51233            Working Professional              Manager                NaN
# 53512            Working Professional              Chemist                NaN
# 59792            Working Professional              Teacher                NaN
# 70403            Working Professional              Chemist                NaN
# 72657            Working Professional    Software Engineer                NaN
# 79092            Working Professional              Manager                NaN
# 79574            Working Professional              Teacher                NaN
# 80241                         Student                  NaN                4.0
# 87983            Working Professional            Architect                NaN
# 88497                         Student                  NaN                2.0
# 89086            Working Professional               Doctor                NaN
# 89094            Working Professional                 Chef                NaN
# 90766                         Student                  NaN                1.0
# 92459            Working Professional     Customer Support                NaN
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 943              NaN  9.96                 3.0               NaN
# 3010             NaN  9.63                 4.0               NaN
# 3297             5.0   NaN                 NaN               1.0
# 12520            NaN  9.39                 3.0               NaN
# 13689            1.0   NaN                 NaN               4.0
# 17405            2.0   NaN                 NaN               2.0
# 23873            3.0   NaN                 NaN               1.0
# 24433            3.0   NaN                 NaN               2.0
# 25799            3.0   NaN                 NaN               5.0
# 29614            2.0   NaN                 NaN               2.0
# 34733            2.0   NaN                 NaN               2.0
# 41144            NaN  8.70                 5.0               NaN
# 41702            2.0   NaN                 NaN               5.0
# 45311            1.0   NaN                 NaN               2.0
# 47608            5.0   NaN                 NaN               3.0
# 47676            NaN  8.73                 4.0               NaN
# 51233            1.0   NaN                 NaN               5.0
# 53512            1.0   NaN                 NaN               3.0
# 59792            2.0   NaN                 NaN               4.0
# 70403            4.0   NaN                 NaN               5.0
# 72657            4.0   NaN                 NaN               4.0
# 79092            2.0   NaN                 NaN               3.0
# 79574            2.0   NaN                 NaN               5.0
# 80241            NaN  5.69                 2.0               NaN
# 87983            4.0   NaN                 NaN               3.0
# 88497            NaN  5.74                 4.0               NaN
# 89086            4.0   NaN                 NaN               1.0
# 89094            4.0   NaN                 NaN               3.0
# 90766            NaN  7.61                 3.0               NaN
# 92459            1.0   NaN                 NaN               5.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 943    More than 8 hours        Healthy       BCA
# 3010           5-6 hours       Moderate  Class 12
# 3297   Less than 5 hours      Unhealthy       BSc
# 12520  Less than 5 hours        Healthy       BSc
# 13689          7-8 hours       Moderate       MBA
# 17405  More than 8 hours      Unhealthy   M.Pharm
# 23873          7-8 hours        Healthy       LLM
# 24433          5-6 hours      Unhealthy       BSc
# 25799          5-6 hours       Moderate        BA
# 29614  Less than 5 hours      Unhealthy        MD
# 34733          7-8 hours       Moderate        BE
# 41144          5-6 hours      Unhealthy       BHM
# 41702  More than 8 hours        Healthy        ME
# 45311          7-8 hours       Moderate      M.Ed
# 47608          5-6 hours        Healthy    B.Arch
# 47676          7-8 hours       Moderate    B.Tech
# 51233          5-6 hours       Moderate       BHM
# 53512  Less than 5 hours       Moderate   M.Pharm
# 59792  Less than 5 hours       Moderate   B.Pharm
# 70403  Less than 5 hours        Healthy      MBBS
# 72657  Less than 5 hours      Unhealthy        BE
# 79092          7-8 hours        Healthy       MHM
# 79574  More than 8 hours      Unhealthy       MBA
# 80241  More than 8 hours      Unhealthy       BSc
# 87983          5-6 hours       Moderate    B.Arch
# 88497          7-8 hours      Unhealthy    B.Tech
# 89086          7-8 hours       Moderate        MD
# 89094  Less than 5 hours        Healthy       BHM
# 90766  Less than 5 hours       Moderate      B.Ed
# 92459  More than 8 hours        Healthy        BA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 943                                     Yes              10.0
# 3010                                     No               3.0
# 3297                                    Yes               7.0
# 12520                                   Yes              10.0
# 13689                                    No              10.0
# 17405                                    No               4.0
# 23873                                    No               7.0
# 24433                                    No               4.0
# 25799                                   Yes               8.0
# 29614                                    No               2.0
# 34733                                   Yes               7.0
# 41144                                   Yes               4.0
# 41702                                   Yes               1.0
# 45311                                   Yes              11.0
# 47608                                    No              12.0
# 47676                                   Yes              10.0
# 51233                                    No               8.0
# 53512                                    No               1.0
# 59792                                    No               3.0
# 70403                                   Yes               1.0
# 72657                                    No               1.0
# 79092                                    No              10.0
# 79574                                    No               8.0
# 80241                                   Yes               8.0
# 87983                                   Yes               1.0
# 88497                                    No               8.0
# 89086                                   Yes              11.0
# 89094                                   Yes               2.0
# 90766                                   Yes               4.0
# 92459                                    No               8.0
#
#        Financial Stress Family History of Mental Illness
# 943                 3.0                              Yes
# 3010                3.0                               No
# 3297                5.0                              Yes
# 12520               4.0                               No
# 13689               5.0                               No
# 17405               2.0                               No
# 23873               4.0                               No
# 24433               1.0                               No
# 25799               1.0                               No
# 29614               5.0                              Yes
# 34733               5.0                               No
# 41144               2.0                               No
# 41702               4.0                               No
# 45311               3.0                               No
# 47608               2.0                               No
# 47676               5.0                              Yes
# 51233               1.0                              Yes
# 53512               5.0                               No
# 59792               4.0                               No
# 70403               5.0                               No
# 72657               5.0                               No
# 79092               3.0                              Yes
# 79574               2.0                              Yes
# 80241               1.0                               No
# 87983               1.0                               No
# 88497               4.0                              Yes
# 89086               3.0                              Yes
# 89094               4.0                              Yes
# 90766               5.0                               No
# 92459               4.0                              Yes
#
#
# Profession
# 20
#            id         Name  Gender   Age         City  \
# 466    141166          Dev    Male  44.0       Meerut
# 15269  155969          Ira  Female  30.0         Agra
# 17733  158433        Pooja  Female  35.0     Varanasi
# 21954  162654       Shivam    Male  49.0       Rajkot
# 26022  166722     Siddhesh    Male  42.0       Nagpur
# 27972  168672        Shrey    Male  21.0    Hyderabad
# 28479  169179          Ira  Female  48.0    Hyderabad
# 35556  176256     Pratyush    Male  48.0    Faridabad
# 38091  178791       Advait    Male  54.0        Surat
# 40598  181298       Harsha    Male  44.0       Rajkot
# 41763  182463       Ishita  Female  46.0       Kanpur
# 46882  187582       Satyam    Male  51.0        Delhi
# 47118  187818       Simran  Female  59.0       Nashik
# 49462  190162       Khushi  Female  31.0        Surat
# 65234  205934  Raghavendra    Male  41.0    Bangalore
# 66793  207493       Khushi  Female  28.0  Vasai-Virar
# 71348  212048         Mira  Female  34.0       Kanpur
# 72549  213249       Kartik    Male  33.0        Surat
# 83938  224638        Ishan    Male  60.0      Kolkata
# 85838  226538        Rashi  Female  26.0       Mumbai
#
#       Working Professional or Student       Profession  Academic Pressure  \
# 466              Working Professional        Unhealthy                NaN
# 15269                         Student               3M                5.0
# 17733            Working Professional        Unhealthy                NaN
# 21954            Working Professional               ME                NaN
# 26022            Working Professional          B.Pharm                NaN
# 27972            Working Professional             24th                NaN
# 28479            Working Professional            Manvi                NaN
# 35556            Working Professional            Samar                NaN
# 38091            Working Professional            Surat                NaN
# 40598            Working Professional               MD                NaN
# 41763            Working Professional             Name                NaN
# 46882            Working Professional              MCA                NaN
# 47118            Working Professional           Simran                NaN
# 49462            Working Professional            Surat                NaN
# 65234            Working Professional               MD                NaN
# 66793                         Student           M.Tech                1.0
# 71348            Working Professional          Surgeon                NaN
# 72549            Working Professional               No                NaN
# 83938            Working Professional  City Consultant                NaN
# 85838            Working Professional          M.Pharm                NaN
#
#        Work Pressure   CGPA  Study Satisfaction  Job Satisfaction  \
# 466              5.0    NaN                 NaN               3.0
# 15269            NaN  10.00                 2.0               NaN
# 17733            1.0    NaN                 NaN               3.0
# 21954            5.0    NaN                 NaN               4.0
# 26022            3.0    NaN                 NaN               3.0
# 27972            3.0    NaN                 NaN               1.0
# 28479            3.0    NaN                 NaN               5.0
# 35556            5.0    NaN                 NaN               3.0
# 38091            1.0    NaN                 NaN               1.0
# 40598            5.0    NaN                 NaN               4.0
# 41763            3.0    NaN                 NaN               2.0
# 46882            4.0    NaN                 NaN               2.0
# 47118            4.0    NaN                 NaN               5.0
# 49462            3.0    NaN                 NaN               5.0
# 65234            4.0    NaN                 NaN               3.0
# 66793            NaN   7.08                 5.0               NaN
# 71348            5.0    NaN                 NaN               4.0
# 72549            5.0    NaN                 NaN               2.0
# 83938            2.0    NaN                 NaN               1.0
# 85838            2.0    NaN                 NaN               2.0
#
#           Sleep Duration Dietary Habits   Degree  \
# 466            5-6 hours      Unhealthy     M.Ed
# 15269  Less than 5 hours      Unhealthy   M.Tech
# 17733          7-8 hours      Unhealthy       BE
# 21954  More than 8 hours      Unhealthy      PhD
# 26022  More than 8 hours        Healthy  M.Pharm
# 27972          5-6 hours      Unhealthy      BCA
# 28479          5-6 hours        Healthy    B.Com
# 35556  Less than 5 hours       Moderate    B.Com
# 38091  Less than 5 hours       Moderate      MSc
# 40598  More than 8 hours        Healthy       MD
# 41763  Less than 5 hours        Healthy      LLB
# 46882          7-8 hours       Moderate      BCA
# 47118          5-6 hours       Moderate      BSc
# 49462  More than 8 hours       Moderate      BBA
# 65234          7-8 hours       Moderate       MD
# 66793          7-8 hours      Unhealthy      MCA
# 71348          7-8 hours       Moderate     MBBS
# 72549  More than 8 hours      Unhealthy      PhD
# 83938  Less than 5 hours       Moderate      BSc
# 85838          5-6 hours      Unhealthy  M.Pharm
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 466                                      No               8.0
# 15269                                   Yes               5.0
# 17733                                   Yes               3.0
# 21954                                    No               9.0
# 26022                                    No               1.0
# 27972                                    No              12.0
# 28479                                    No               7.0
# 35556                                    No               6.0
# 38091                                    No               2.0
# 40598                                    No               5.0
# 41763                                   Yes               8.0
# 46882                                    No              12.0
# 47118                                   Yes               9.0
# 49462                                    No               6.0
# 65234                                   Yes              12.0
# 66793                                    No               5.0
# 71348                                    No               0.0
# 72549                                   Yes              10.0
# 83938                                   Yes               8.0
# 85838                                   Yes               6.0
#
#        Financial Stress Family History of Mental Illness
# 466                 3.0                              Yes
# 15269               5.0                              Yes
# 17733               5.0                               No
# 21954               4.0                              Yes
# 26022               3.0                               No
# 27972               1.0                              Yes
# 28479               4.0                              Yes
# 35556               3.0                              Yes
# 38091               2.0                               No
# 40598               3.0                              Yes
# 41763               2.0                               No
# 46882               3.0                              Yes
# 47118               5.0                              Yes
# 49462               2.0                              Yes
# 65234               3.0                              Yes
# 66793               2.0                               No
# 71348               2.0                               No
# 72549               2.0                               No
# 83938               5.0                              Yes
# 85838               2.0                              Yes
#
#
# Sleep Duration
# 11
#            id     Name  Gender   Age         City  \
# 523    141223     Vani  Female  38.0     Varanasi
# 3593   144293    Rajat    Male  45.0        Delhi
# 12812  153512     Anvi  Female  33.0  Vasai-Virar
# 15598  156298     Ansh    Male  38.0  Vasai-Virar
# 27151  167851     Isha  Female  36.0     Ludhiana
# 38028  178728  Bhavesh    Male  39.0       Jaipur
# 40522  181222      Jai    Male  49.0      Kolkata
# 41265  181965    Anaya  Female  28.0  Vasai-Virar
# 47745  188445    Rupak    Male  39.0     Srinagar
# 48067  188767   Vedant    Male  45.0     Ludhiana
# 68957  209657  Krishna    Male  45.0      Chennai
#
#       Working Professional or Student         Profession  Academic Pressure  \
# 523              Working Professional             Lawyer                NaN
# 3593             Working Professional        Electrician                NaN
# 12812                         Student                NaN                3.0
# 15598            Working Professional     Content Writer                NaN
# 27151            Working Professional     UX/UI Designer                NaN
# 38028            Working Professional            Teacher                NaN
# 40522            Working Professional    Sales Executive                NaN
# 41265            Working Professional            Teacher                NaN
# 47745            Working Professional  Financial Analyst                NaN
# 48067            Working Professional            Teacher                NaN
# 68957            Working Professional   Digital Marketer                NaN
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 523              1.0   NaN                 NaN               4.0
# 3593             4.0   NaN                 NaN               4.0
# 12812            NaN  9.97                 1.0               NaN
# 15598            4.0   NaN                 NaN               1.0
# 27151            1.0   NaN                 NaN               4.0
# 38028            5.0   NaN                 NaN               4.0
# 40522            2.0   NaN                 NaN               5.0
# 41265            4.0   NaN                 NaN               2.0
# 47745            4.0   NaN                 NaN               3.0
# 48067            4.0   NaN                 NaN               1.0
# 68957            3.0   NaN                 NaN               2.0
#
#                             Sleep Duration Dietary Habits  Degree  \
# 523                                      0      Unhealthy     LLM
# 3593                                Meerut      Unhealthy     PhD
# 12812                          60-65 hours      Unhealthy     BSc
# 15598                                Vivan      Unhealthy     BSc
# 27151                               Meerut        Healthy     PhD
# 38028                           8-89 hours        Healthy  M.Tech
# 40522  Have_you_ever_had_suicidal_thoughts        Healthy     MBA
# 41265                          20-21 hours       Moderate     LLM
# 47745                              6 hours        Healthy   M.Com
# 48067                          50-75 hours      Unhealthy     LLM
# 68957                           9-10 hours        Healthy      BA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 523                                      No               1.0
# 3593                                     No               0.0
# 12812                                   Yes               0.0
# 15598                                   Yes               6.0
# 27151                                   Yes              12.0
# 38028                                    No               1.0
# 40522                                   Yes               3.0
# 41265                                   Yes              10.0
# 47745                                   Yes               1.0
# 48067                                    No               0.0
# 68957                                    No               3.0
#
#        Financial Stress Family History of Mental Illness
# 523                 4.0                               No
# 3593                1.0                               No
# 12812               2.0                              Yes
# 15598               4.0                              Yes
# 27151               3.0                              Yes
# 38028               1.0                               No
# 40522               2.0                               No
# 41265               4.0                              Yes
# 47745               5.0                               No
# 48067               3.0                               No
# 68957               1.0                               No
#
#
# Dietary Habits
# 13
#            id       Name  Gender   Age         City  \
# 13247  153947     Prachi  Female  42.0     Vadodara
# 16449  157149  Kartikeya    Male  33.0    Hyderabad
# 42136  182836    Nishant    Male  42.0     Srinagar
# 45550  186250    Bhavesh    Male  46.0  Vasai-Virar
# 60092  200792       Vivi  Female  29.0       Jaipur
# 66895  207595      Rajat    Male  52.0         Pune
# 70001  210701     Armaan    Male  54.0    Hyderabad
# 75911  216611    Sanjeev    Male  54.0      Chennai
# 81565  222265       Anvi  Female  51.0      Chennai
# 82653  223353      Rohan    Male  47.0       Jaipur
# 84717  225417   Abhishek    Male  49.0    Hyderabad
# 87592  228292      Sanya  Female  30.0      Kolkata
# 92777  233477      Vibha  Female  26.0      Chennai
#
#       Working Professional or Student           Profession  Academic Pressure  \
# 13247            Working Professional              Teacher                NaN
# 16449                         Student                  NaN                4.0
# 42136            Working Professional           Consultant                NaN
# 45550            Working Professional               Lawyer                NaN
# 60092                         Student                  NaN                3.0
# 66895            Working Professional              Teacher                NaN
# 70001            Working Professional              Teacher                NaN
# 75911            Working Professional           HR Manager                NaN
# 81565            Working Professional                 Chef                NaN
# 82653            Working Professional     Business Analyst                NaN
# 84717            Working Professional       Content Writer                NaN
# 87592                         Student                  NaN                4.0
# 92777            Working Professional  Finanancial Analyst                NaN
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 13247            3.0   NaN                 NaN               5.0
# 16449            NaN  8.59                 3.0               NaN
# 42136            1.0   NaN                 NaN               1.0
# 45550            3.0   NaN                 NaN               5.0
# 60092            NaN  8.70                 4.0               NaN
# 66895            4.0   NaN                 NaN               3.0
# 70001            2.0   NaN                 NaN               5.0
# 75911            1.0   NaN                 NaN               3.0
# 81565            2.0   NaN                 NaN               3.0
# 82653            3.0   NaN                 NaN               5.0
# 84717            5.0   NaN                 NaN               5.0
# 87592            NaN  6.89                 2.0               NaN
# 92777            4.0   NaN                 NaN               2.0
#
#           Sleep Duration Dietary Habits   Degree  \
# 13247          5-6 hours         Prachi  B.Pharm
# 16449          7-8 hours          Mealy       MD
# 42136          5-6 hours      Resistant       BE
# 45550          5-6 hours            MCA      LLM
# 60092          5-6 hours      5 Healthy    B.Com
# 66895  More than 8 hours       Academic       MA
# 70001  Less than 5 hours    Educational     B.Ed
# 75911          5-6 hours          Soham       MA
# 81565          7-8 hours    5 Unhealthy      BHM
# 82653          7-8 hours         Vivaan    B.Com
# 84717          7-8 hours         Raghav       BE
# 87592          7-8 hours          Naina       MA
# 92777          7-8 hours        Kolkata      BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 13247                                    No               2.0
# 16449                                   Yes               8.0
# 42136                                    No              10.0
# 45550                                   Yes               2.0
# 60092                                   Yes               4.0
# 66895                                    No              11.0
# 70001                                   Yes              12.0
# 75911                                    No               9.0
# 81565                                    No               1.0
# 82653                                   Yes               5.0
# 84717                                    No               0.0
# 87592                                   Yes               1.0
# 92777                                    No               8.0
#
#        Financial Stress Family History of Mental Illness
# 13247               1.0                              Yes
# 16449               1.0                              Yes
# 42136               5.0                               No
# 45550               2.0                              Yes
# 60092               1.0                               No
# 66895               5.0                              Yes
# 70001               5.0                              Yes
# 75911               3.0                               No
# 81565               4.0                               No
# 82653               1.0                              Yes
# 84717               3.0                              Yes
# 87592               2.0                              Yes
# 92777               2.0                               No
#
#
# Degree
# 48
#            id       Name  Gender   Age           City  \
# 118    140818      Rohan    Male  46.0        Kolkata
# 1887   142587     Aadhya  Female  26.0         Rajkot
# 3856   144556     Garima  Female  49.0         Nashik
# 7341   148041   Rudransh    Male  26.0         Bhopal
# 7894   148594     Prachi  Female  19.0      Ahmedabad
# 9147   149847    Reyansh    Male  54.0         Meerut
# 12466  153166     Anjali  Female  29.0         Nashik
# 12862  153562  Aishwarya  Female  48.0       Vadodara
# 13441  154141      Aditi  Female  56.0          Thane
# 16160  156860       Anvi  Female  40.0    Vasai-Virar
# 17638  158338       Yash    Male  32.0         Mumbai
# 19161  159861      Arnav    Male  47.0           Pune
# 20934  161634      Rahil    Male  57.0          Surat
# 24688  165388     Aahana  Female  39.0          Surat
# 26733  167433     Garima  Female  30.0         Indore
# 29693  170393     Tushar    Male  47.0      Ghaziabad
# 31088  171788    Nandini  Female  55.0       Vadodara
# 33213  173913     Satyam    Male  45.0      Ghaziabad
# 33433  174133       Shiv    Male  25.0          Patna
# 36127  176827      Ishan    Male  47.0      Ahmedabad
# 36474  177174       Arav    Male  27.0      Ghaziabad
# 37010  177710       Ansh    Male  44.0        Kolkata
# 46899  187599      Rajat    Male  58.0         Bhopal
# 49208  189908      Ayaan    Male  33.0       Ludhiana
# 49445  190145      Divya  Female  55.0       Varanasi
# 52598  193298     Simran  Female  23.0      Ahmedabad
# 55085  195785     Armaan    Male  28.0       Srinagar
# 56319  197019     Siddhi  Female  59.0      Faridabad
# 56484  197184     Armaan    Male  57.0       Vadodara
# 60126  200826      Janvi  Female  38.0       Varanasi
# 61034  201734      Gagan    Male  38.0         Nagpur
# 61187  201887      Kiran    Male  32.0       Ludhiana
# 61190  201890      Gagan    Male  57.0         Nashik
# 62459  203159     Eshita  Female  56.0       Varanasi
# 63858  204558     Vrinda  Female  21.0         Nagpur
# 67704  208404        Jai    Male  51.0         Rajkot
# 68389  209089     Himani  Female  45.0       Varanasi
# 72714  213414      Rajat    Male  52.0          Patna
# 72849  213549      Sanya  Female  60.0        Lucknow
# 73471  214171      Rajat    Male  26.0       Varanasi
# 77080  217780      Tanya  Female  58.0       Vadodara
# 77285  217985   Siddhesh    Male  50.0  Visakhapatnam
# 81738  222438     Armaan    Male  45.0         Kalyan
# 88108  228808     Pranav    Male  33.0         Meerut
# 89240  229940     Aadhya  Female  30.0          Vidya
# 90152  230852   Shivansh    Male  26.0         Rajkot
# 90338  231038       Viya  Female  36.0  Visakhapatnam
# 92192  232892      Divya  Female  47.0          Surat
#
#       Working Professional or Student              Profession  \
# 118              Working Professional       Software Engineer
# 1887                          Student                     NaN
# 3856             Working Professional                     NaN
# 7341                          Student                     NaN
# 7894             Working Professional     Mechanical Engineer
# 9147             Working Professional       Travel Consultant
# 12466                         Student                     NaN
# 12862            Working Professional       Marketing Manager
# 13441            Working Professional          UX/UI Designer
# 16160            Working Professional             Electrician
# 17638                         Student                     NaN
# 19161            Working Professional     Finanancial Analyst
# 20934            Working Professional       Travel Consultant
# 24688            Working Professional                     NaN
# 26733                         Student                     NaN
# 29693            Working Professional         Sales Executive
# 31088            Working Professional                 Chemist
# 33213            Working Professional                 Plumber
# 33433            Working Professional        Business Analyst
# 36127            Working Professional       Financial Analyst
# 36474            Working Professional                 Manager
# 37010            Working Professional                 Teacher
# 46899            Working Professional                 Teacher
# 49208                         Student                     NaN
# 49445            Working Professional       Marketing Manager
# 52598            Working Professional       Software Engineer
# 55085                         Student                     NaN
# 56319            Working Professional                   Pilot
# 56484            Working Professional                 Teacher
# 60126            Working Professional                 Teacher
# 61034            Working Professional          Content Writer
# 61187                         Student                     NaN
# 61190            Working Professional                 Teacher
# 62459            Working Professional              Researcher
# 63858                         Student                     NaN
# 67704            Working Professional       Financial Analyst
# 68389            Working Professional          Civil Engineer
# 72714            Working Professional     Finanancial Analyst
# 72849            Working Professional  Educational Consultant
# 73471                         Student                     NaN
# 77080            Working Professional        Graphic Designer
# 77285            Working Professional        Graphic Designer
# 81738            Working Professional                 Teacher
# 88108                         Student                     NaN
# 89240            Working Professional                 Teacher
# 90152                         Student                     NaN
# 90338            Working Professional                 Chemist
# 92192            Working Professional                 Teacher
#
#        Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 118                  NaN            1.0   NaN                 NaN
# 1887                 4.0            NaN  8.17                 1.0
# 3856                 NaN            3.0   NaN                 NaN
# 7341                 2.0            NaN  8.13                 4.0
# 7894                 NaN            5.0   NaN                 NaN
# 9147                 NaN            1.0   NaN                 NaN
# 12466                2.0            NaN  9.39                 3.0
# 12862                NaN            4.0   NaN                 NaN
# 13441                NaN            1.0   NaN                 NaN
# 16160                NaN            3.0   NaN                 NaN
# 17638                2.0            NaN  5.38                 4.0
# 19161                NaN            4.0   NaN                 NaN
# 20934                NaN            2.0   NaN                 NaN
# 24688                NaN            3.0   NaN                 NaN
# 26733                3.0            NaN  7.90                 2.0
# 29693                NaN            4.0   NaN                 NaN
# 31088                NaN            1.0   NaN                 NaN
# 33213                NaN            1.0   NaN                 NaN
# 33433                NaN            4.0   NaN                 NaN
# 36127                NaN            5.0   NaN                 NaN
# 36474                NaN            4.0   NaN                 NaN
# 37010                NaN            1.0   NaN                 NaN
# 46899                NaN            5.0   NaN                 NaN
# 49208                3.0            NaN  5.84                 3.0
# 49445                NaN            4.0   NaN                 NaN
# 52598                NaN            4.0   NaN                 NaN
# 55085                5.0            NaN  7.72                 5.0
# 56319                NaN            1.0   NaN                 NaN
# 56484                NaN            5.0   NaN                 NaN
# 60126                NaN            1.0   NaN                 NaN
# 61034                NaN            4.0   NaN                 NaN
# 61187                4.0            NaN  7.77                 5.0
# 61190                NaN            4.0   NaN                 NaN
# 62459                NaN            5.0   NaN                 NaN
# 63858                5.0            NaN  6.79                 4.0
# 67704                NaN            3.0   NaN                 NaN
# 68389                NaN            2.0   NaN                 NaN
# 72714                NaN            3.0   NaN                 NaN
# 72849                NaN            1.0   NaN                 NaN
# 73471                4.0            NaN  8.24                 4.0
# 77080                NaN            2.0   NaN                 NaN
# 77285                NaN            5.0   NaN                 NaN
# 81738                NaN            1.0   NaN                 NaN
# 88108                1.0            NaN  8.95                 4.0
# 89240                NaN            1.0   NaN                 NaN
# 90152                4.0            NaN  9.96                 4.0
# 90338                NaN            3.0   NaN                 NaN
# 92192                NaN            3.0   NaN                 NaN
#
#        Job Satisfaction     Sleep Duration Dietary Habits  \
# 118                 3.0          7-8 hours        Healthy
# 1887                NaN  More than 8 hours      Unhealthy
# 3856                4.0  More than 8 hours       Moderate
# 7341                NaN  Less than 5 hours      Unhealthy
# 7894                4.0  More than 8 hours        Healthy
# 9147                3.0          5-6 hours      Unhealthy
# 12466               NaN  Less than 5 hours       Moderate
# 12862               4.0          5-6 hours      Unhealthy
# 13441               2.0  More than 8 hours        Healthy
# 16160               4.0  Less than 5 hours      Unhealthy
# 17638               NaN          7-8 hours        Healthy
# 19161               2.0          5-6 hours        Healthy
# 20934               3.0          7-8 hours        Healthy
# 24688               4.0  More than 8 hours      Unhealthy
# 26733               NaN          5-6 hours       Moderate
# 29693               2.0  Less than 5 hours       Moderate
# 31088               4.0  More than 8 hours      Unhealthy
# 33213               4.0          5-6 hours      Unhealthy
# 33433               3.0          5-6 hours       Moderate
# 36127               2.0          7-8 hours       Moderate
# 36474               4.0          5-6 hours        Healthy
# 37010               2.0          7-8 hours      Unhealthy
# 46899               3.0          7-8 hours       Moderate
# 49208               NaN  Less than 5 hours        Healthy
# 49445               5.0  Less than 5 hours       Moderate
# 52598               1.0          5-6 hours      Unhealthy
# 55085               NaN          7-8 hours       Moderate
# 56319               5.0  Less than 5 hours       Moderate
# 56484               1.0          7-8 hours        Healthy
# 60126               4.0  Less than 5 hours      Unhealthy
# 61034               1.0          5-6 hours      Unhealthy
# 61187               NaN          7-8 hours      Unhealthy
# 61190               3.0  More than 8 hours      Unhealthy
# 62459               4.0  More than 8 hours        Healthy
# 63858               NaN  More than 8 hours        Healthy
# 67704               2.0          7-8 hours       Moderate
# 68389               4.0          5-6 hours       Moderate
# 72714               3.0  Less than 5 hours      Unhealthy
# 72849               2.0  More than 8 hours       Moderate
# 73471               NaN          5-6 hours       Moderate
# 77080               4.0  More than 8 hours      Unhealthy
# 77285               3.0  More than 8 hours       Moderate
# 81738               2.0          7-8 hours      Unhealthy
# 88108               NaN          5-6 hours       Moderate
# 89240               5.0  Less than 5 hours       Moderate
# 90152               NaN          7-8 hours       Moderate
# 90338               1.0          7-8 hours        Healthy
# 92192               5.0          5-6 hours        Healthy
#
#                     Degree Have you ever had suicidal thoughts ?  \
# 118                  BTech                                   Yes
# 1887             B. Gender                                   Yes
# 3856         B.Study_Hours                                   Yes
# 7341                  A.Ed                                   Yes
# 7894   Mechanical Engineer                                    No
# 9147                   B.H                                    No
# 12466                 M.UI                                   Yes
# 12862                Vibha                                   Yes
# 13441                B BCA                                    No
# 16160              B.Press                                    No
# 17638                Gagan                                    No
# 19161                BTech                                   Yes
# 20934    Travel Consultant                                    No
# 24688                 5.65                                    No
# 26733               Eshita                                    No
# 29693                B_Com                                    No
# 31088             B._Pharm                                    No
# 33213                 Pune                                    No
# 33433                 Bian                                    No
# 36127              B.M.Com                                    No
# 36474                Kavya                                   Yes
# 37010               M.M.Ed                                    No
# 46899                 E.Ed                                   Yes
# 49208                  3.0                                   Yes
# 49445              B.M.Com                                    No
# 52598                BTech                                   Yes
# 55085                  3.0                                   Yes
# 56319                Moham                                   Yes
# 56484                 B.BA                                    No
# 60126                 I.Ed                                    No
# 61034               Eshita                                   Yes
# 61187                 M.UI                                    No
# 61190                Magan                                    No
# 62459             B B.Tech                                    No
# 63858               M.B.Ed                                   Yes
# 67704  B Financial Analyst                                   Yes
# 68389                  GCA                                   Yes
# 72714                BTech                                    No
# 72849                 G.Ed                                    No
# 73471                Rupak                                    No
# 77080                 B.CA                                   Yes
# 77285                  PCA                                   Yes
# 81738                 J.Ed                                    No
# 88108                 8.95                                    No
# 89240               Aadhya                                   Yes
# 90152              Banchal                                    No
# 90338                   M.                                   Yes
# 92192                 BHCA                                    No
#
#        Work/Study Hours  Financial Stress Family History of Mental Illness
# 118                 7.0               2.0                               No
# 1887                4.0               2.0                               No
# 3856                8.0               1.0                              Yes
# 7341                4.0               4.0                               No
# 7894                1.0               1.0                              Yes
# 9147                2.0               5.0                              Yes
# 12466               2.0               4.0                               No
# 12862               3.0               1.0                               No
# 13441               2.0               5.0                              Yes
# 16160               5.0               2.0                              Yes
# 17638              12.0               1.0                              Yes
# 19161               5.0               2.0                              Yes
# 20934               0.0               3.0                               No
# 24688               0.0               2.0                               No
# 26733              10.0               4.0                               No
# 29693               0.0               1.0                              Yes
# 31088              10.0               1.0                              Yes
# 33213              11.0               2.0                              Yes
# 33433              10.0               1.0                              Yes
# 36127               7.0               2.0                               No
# 36474               4.0               1.0                              Yes
# 37010               5.0               5.0                              Yes
# 46899              11.0               1.0                               No
# 49208               2.0               1.0                               No
# 49445               0.0               5.0                              Yes
# 52598              10.0               2.0                               No
# 55085              10.0               5.0                               No
# 56319               2.0               1.0                               No
# 56484               2.0               1.0                               No
# 60126              12.0               4.0                               No
# 61034               6.0               3.0                              Yes
# 61187               9.0               3.0                               No
# 61190               4.0               5.0                              Yes
# 62459              11.0               5.0                              Yes
# 63858              11.0               2.0                              Yes
# 67704               6.0               1.0                              Yes
# 68389              10.0               1.0                              Yes
# 72714               2.0               4.0                              Yes
# 72849               7.0               4.0                               No
# 73471               8.0               1.0                              Yes
# 77080              11.0               3.0                               No
# 77285               2.0               4.0                               No
# 81738              10.0               4.0                              Yes
# 88108              11.0               5.0                              Yes
# 89240               5.0               4.0                              Yes
# 90152              10.0               4.0                              Yes
# 90338               4.0               5.0                               No
# 92192               5.0               2.0                              Yes
#
#
#            id      Name  Gender   Age               City  \
# 943    141643     Kunal    Male  21.0             Malyan
# 3010   143710    Advait    Male  20.0  Less than 5 hours
# 3297   143997    Aadhya  Female  23.0              Aditi
# 12520  153220    Khushi  Female  24.0             Mhopal
# 13689  154389       Ila  Female  47.0               Avni
# ...       ...       ...     ...   ...                ...
# 88108  228808    Pranav    Male  33.0             Meerut
# 89240  229940    Aadhya  Female  30.0              Vidya
# 90152  230852  Shivansh    Male  26.0             Rajkot
# 90338  231038      Viya  Female  36.0      Visakhapatnam
# 92192  232892     Divya  Female  47.0              Surat
#
#       Working Professional or Student    Profession  Academic Pressure  \
# 943                           Student           NaN                5.0
# 3010                          Student           NaN                1.0
# 3297             Working Professional    Consultant                NaN
# 12520                         Student           NaN                3.0
# 13689            Working Professional  Entrepreneur                NaN
# ...                               ...           ...                ...
# 88108                         Student           NaN                1.0
# 89240            Working Professional       Teacher                NaN
# 90152                         Student           NaN                4.0
# 90338            Working Professional       Chemist                NaN
# 92192            Working Professional       Teacher                NaN
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 943              NaN  9.96                 3.0               NaN
# 3010             NaN  9.63                 4.0               NaN
# 3297             5.0   NaN                 NaN               1.0
# 12520            NaN  9.39                 3.0               NaN
# 13689            1.0   NaN                 NaN               4.0
# ...              ...   ...                 ...               ...
# 88108            NaN  8.95                 4.0               NaN
# 89240            1.0   NaN                 NaN               5.0
# 90152            NaN  9.96                 4.0               NaN
# 90338            3.0   NaN                 NaN               1.0
# 92192            3.0   NaN                 NaN               5.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 943    More than 8 hours        Healthy       BCA
# 3010           5-6 hours       Moderate  Class 12
# 3297   Less than 5 hours      Unhealthy       BSc
# 12520  Less than 5 hours        Healthy       BSc
# 13689          7-8 hours       Moderate       MBA
# ...                  ...            ...       ...
# 88108          5-6 hours       Moderate      8.95
# 89240  Less than 5 hours       Moderate    Aadhya
# 90152          7-8 hours       Moderate   Banchal
# 90338          7-8 hours        Healthy        M.
# 92192          5-6 hours        Healthy      BHCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 943                                     Yes              10.0
# 3010                                     No               3.0
# 3297                                    Yes               7.0
# 12520                                   Yes              10.0
# 13689                                    No              10.0
# ...                                     ...               ...
# 88108                                    No              11.0
# 89240                                   Yes               5.0
# 90152                                    No              10.0
# 90338                                   Yes               4.0
# 92192                                    No               5.0
#
#        Financial Stress Family History of Mental Illness
# 943                 3.0                              Yes
# 3010                3.0                               No
# 3297                5.0                              Yes
# 12520               4.0                               No
# 13689               5.0                               No
# ...                 ...                              ...
# 88108               5.0                              Yes
# 89240               4.0                              Yes
# 90152               4.0                              Yes
# 90338               5.0                               No
# 92192               2.0                              Yes
#
# [122 rows x 19 columns]
# (122, 19)

# %% [markdown]
# finding: 122 rows in test data have values that are not included in train data for some columns<br>
# following step: use the most frequent value in train data for these rows

# %% [markdown]
# ### use the most frequent value in train data for these outlier rows

# %%
# Loop through each category to identify and handle outliers
for category in categories:
    # Get unique values for the category in test and train datasets
    test_unique = pd.Series(test[category].unique())  # Convert to Series
    train_unique = pd.Series(train[category].unique())  # Convert to Series

    # Identify outlier values (present in test but not in train)
    unmatched_values = test_unique[~test_unique.isin(train_unique)]

    # Check if there are any outliers
    if len(unmatched_values) > 0:
        outliers_count = len(test[test[category].isin(unmatched_values)])

        print(f"{outliers_count} Outliers found in category: {category}")

        # Get the mode (most frequent value) for the category in train
        most_frequent_value = train[category].mode()[
            0
        ]  # Mode always returns a Series, take the first value

        # Replace the outlier values in test data with the most frequent value from train
        test.loc[test[category].isin(unmatched_values), category] = most_frequent_value

        print(
            f"Replaced outlier values in category '{category}' with '{most_frequent_value}'\n"
        )
# Out:
# 30 Outliers found in category: City
# Replaced outlier values in category 'City' with 'Kalyan'
#
# 20 Outliers found in category: Profession
# Replaced outlier values in category 'Profession' with 'Teacher'
#
# 11 Outliers found in category: Sleep Duration
# Replaced outlier values in category 'Sleep Duration' with 'Less than 5 hours'
#
# 13 Outliers found in category: Dietary Habits
# Replaced outlier values in category 'Dietary Habits' with 'Moderate'
#
# 48 Outliers found in category: Degree
# Replaced outlier values in category 'Degree' with 'Class 12'

# %% [markdown]
# ### check for NAs

# %%
## split data based on Working Professional or Student
train_student = train[train["Working Professional or Student"] == "Student"]
train_professional = train[
    train["Working Professional or Student"] == "Working Professional"
]
test_student = test[test["Working Professional or Student"] == "Student"]
test_professional = test[
    test["Working Professional or Student"] == "Working Professional"
]

# Define the columns to process for each DataFrame
train_student_na_columns = ["Academic Pressure", "CGPA", "Study Satisfaction", "Dietary Habits", "Financial Stress"]
train_professional_na_columns = ["Work Pressure", "Job Satisfaction", "Profession", "Dietary Habits", "Degree", "Financial Stress"]
test_student_na_columns = ["Academic Pressure", "CGPA", "Study Satisfaction", "Dietary Habits", "Degree"]
test_professional_na_columns = ["Work Pressure", "Job Satisfaction", "Profession", "Dietary Habits", "Degree"]

# Replace missing values in train_student for the listed columns
for col in train_student_na_columns:
    train_student.loc[:, col] = train_student[col].fillna(train_student[col].mode()[0])

# Replace missing values in train_professional for the listed columns
for col in train_professional_na_columns:
    train_professional.loc[:, col] = train_professional[col].fillna(train_professional[col].mode()[0])

# Replace missing values in test_student for the listed columns
for col in test_student_na_columns:
    test_student.loc[:, col] = test_student[col].fillna(test_student[col].mode()[0])

# Replace missing values in test_professional for the listed columns
for col in test_professional_na_columns:
    test_professional.loc[:, col] = test_professional[col].fillna(test_professional[col].mode()[0])

# check nas in updated DataFrames
print("Updated train_student:")
print(train_student.isna().sum())

print("\nUpdated train_professional:")
print(train_professional.isna().sum())

print("\nUpdated test_student:")
print(test_student.isna().sum())

print("\nUpdated test_professional:")
print(test_professional.isna().sum())
# Out:
# Updated train_student:
# id                                           0
# Name                                         0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                               27867
# Academic Pressure                            0
# Work Pressure                            27898
# CGPA                                         0
# Study Satisfaction                           0
# Job Satisfaction                         27893
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# Depression                                   0
# dtype: int64
#
# Updated train_professional:
# id                                            0
# Name                                          0
# Gender                                        0
# Age                                           0
# City                                          0
# Working Professional or Student               0
# Profession                                    0
# Academic Pressure                        112794
# Work Pressure                                 0
# CGPA                                     112793
# Study Satisfaction                       112793
# Job Satisfaction                              0
# Sleep Duration                                0
# Dietary Habits                                0
# Degree                                        0
# Have you ever had suicidal thoughts ?         0
# Work/Study Hours                              0
# Financial Stress                              0
# Family History of Mental Illness              0
# Depression                                    0
# dtype: int64
#
# Updated test_student:
# id                                           0
# Name                                         0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                               18746
# Academic Pressure                            0
# Work Pressure                            18768
# CGPA                                         0
# Study Satisfaction                           0
# Job Satisfaction                         18765
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# dtype: int64
#
# Updated test_professional:
# id                                           0
# Name                                         0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                                   0
# Academic Pressure                        75026
# Work Pressure                                0
# CGPA                                     75025
# Study Satisfaction                       75025
# Job Satisfaction                             0
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# dtype: int64

# %% [markdown]
# ### combine data

# %%
train_new = pd.concat([train_student, train_professional])
test_new = pd.concat([test_student, test_professional])
print(train.shape)
print(test.shape)
print(train_new.shape)
print(test_new.shape)
print(train_new.head())
print(test_new.head())
train_new.to_csv("train_new.csv", index=False)
test_new.to_csv("test_new.csv", index=False)
# Out:
# (140700, 20)
# (93800, 19)
# (140700, 20)
# (93800, 19)
#     id       Name  Gender   Age           City  \
# 2    2     Yuvraj    Male  33.0  Visakhapatnam
# 8    8  Aishwarya  Female  24.0      Bangalore
# 26  26     Aditya    Male  31.0       Srinagar
# 30  30     Prisha  Female  28.0       Varanasi
# 32  32     Chhavi  Female  25.0         Jaipur
#
#    Working Professional or Student Profession  Academic Pressure  \
# 2                          Student        NaN                5.0
# 8                          Student        NaN                2.0
# 26                         Student        NaN                3.0
# 30                         Student        NaN                3.0
# 32                         Student        NaN                4.0
#
#     Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 2             NaN  8.97                 2.0               NaN
# 8             NaN  5.90                 5.0               NaN
# 26            NaN  7.03                 5.0               NaN
# 30            NaN  5.59                 2.0               NaN
# 32            NaN  8.13                 3.0               NaN
#
#        Sleep Duration Dietary Habits   Degree  \
# 2           5-6 hours        Healthy  B.Pharm
# 8           5-6 hours       Moderate      BSc
# 26  Less than 5 hours        Healthy       BA
# 30          7-8 hours       Moderate      BCA
# 32          5-6 hours       Moderate   M.Tech
#
#    Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 2                                    Yes               3.0               1.0
# 8                                     No               3.0               2.0
# 26                                    No               9.0               1.0
# 30                                   Yes               4.0               5.0
# 32                                   Yes               1.0               1.0
#
#    Family History of Mental Illness  Depression
# 2                                No           1
# 8                               Yes           0
# 26                              Yes           0
# 30                              Yes           1
# 32                               No           0
#         id    Name  Gender   Age           City  \
# 3   140703  Nalini  Female  23.0         Rajkot
# 8   140708   Navya  Female  21.0          Surat
# 19  140719   Kiran    Male  28.0        Lucknow
# 20  140720   Rashi  Female  26.0      Ghaziabad
# 21  140721   Manan    Male  32.0  Visakhapatnam
#
#    Working Professional or Student Profession  Academic Pressure  \
# 3                          Student        NaN                5.0
# 8                          Student        NaN                1.0
# 19                         Student        NaN                5.0
# 20                         Student        NaN                3.0
# 21                         Student        NaN                3.0
#
#     Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3             NaN  6.84                 1.0               NaN
# 8             NaN  7.39                 3.0               NaN
# 19            NaN  6.03                 3.0               NaN
# 20            NaN  8.63                 5.0               NaN
# 21            NaN  8.61                 1.0               NaN
#
#        Sleep Duration Dietary Habits Degree  \
# 3   More than 8 hours       Moderate    BSc
# 8   Less than 5 hours        Healthy    BBA
# 19          7-8 hours       Moderate     MA
# 20  More than 8 hours       Moderate    BBA
# 21  Less than 5 hours       Moderate   M.Ed
#
#    Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 3                                    Yes              10.0               4.0
# 8                                     No               8.0               1.0
# 19                                    No              11.0               3.0
# 20                                   Yes              10.0               4.0
# 21                                   Yes              11.0               5.0
#
#    Family History of Mental Illness
# 3                                No
# 8                               Yes
# 19                              Yes
# 20                              Yes
# 21                               No

# %% [markdown]
# ## Build Model

# %%
from sklearn.model_selection import train_test_split
from category_encoders import TargetEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

def preprocess_data(train_data, test_data, features, target_column):
    """
    Preprocesses the train and test data:
    - Selects specific features
    - Encodes categorical variables
    """
    # Select specified features
    X_train = train_data[features]
    y_train = train_data[target_column]
    X_test = test_data[features]

    # Encode categorical variables using Target Encoding
    categorical_cols = X_train.select_dtypes(include=['object']).columns
    encoder = TargetEncoder(cols=categorical_cols)
    X_train_encoded = encoder.fit_transform(X_train, y_train)
    X_test_encoded = encoder.transform(X_test)

    return X_train_encoded, y_train, X_test_encoded

def train_and_predict(X_train, y_train, X_test, output_column_name):
    """
    Trains a stacking classifier and makes predictions on the test data.
    """
    # Train-test split for validation
    X_train_split, X_val, y_train_split, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

    # Define base models
    base_models = [
        ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
        ('gb', GradientBoostingClassifier(n_estimators=100, random_state=42))
    ]

    # Define meta-model
    meta_model = LogisticRegression()

    # Build stacking classifier
    stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5)
    stacking_clf.fit(X_train_split, y_train_split)

    # Validate the model
    y_val_pred = stacking_clf.predict(X_val)
    accuracy = accuracy_score(y_val, y_val_pred)
    print(f"Validation Accuracy ({output_column_name}): {accuracy:.2f}")

    # Predict on the test data
    predictions = stacking_clf.predict(X_test)

    return predictions

# Features for student and professional models
student_features = [
    'Gender', 'Age', 'City', 'Academic Pressure', 'CGPA', 'Study Satisfaction', 'Sleep Duration', 
    'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 
    'Financial Stress', 'Family History of Mental Illness'
]
professional_features = [
    'Gender', 'Age', 'City', 'Profession', 'Work Pressure', 'Job Satisfaction', 'Sleep Duration', 
    'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 
    'Financial Stress', 'Family History of Mental Illness'
]

# Preprocess and train models
if __name__ == "__main__":
    # Train on train_student and predict on test_student
    X_train_student, y_train_student, X_test_student = preprocess_data(train_student, test_student, student_features, 'Depression')
    student_predictions = train_and_predict(X_train_student, y_train_student, X_test_student, 'Student')

    # Train on train_professional and predict on test_professional
    X_train_professional, y_train_professional, X_test_professional = preprocess_data(train_professional, test_professional, professional_features, 'Depression')
    professional_predictions = train_and_predict(X_train_professional, y_train_professional, X_test_professional, 'Professional')

    # Add predictions to respective test datasets
    test_student['Depression_Predicted'] = student_predictions
    test_professional['Depression_Predicted'] = professional_predictions

    # Combine the results
    test_combined = pd.concat([test_student, test_professional], ignore_index=True)

    # Output only 'id' and 'Depression_Predicted'
    output_file = 'test_new_with_predictions.csv'
    output_df = test_combined[['id', 'Depression_Predicted']]
    output_df.to_csv(output_file, index=False)

    # Display the first few rows of the output
    print(output_df.head())
# Out:
# Validation Accuracy (Student): 0.84
# Validation Accuracy (Professional): 0.96
#        id  Depression_Predicted
# 0  140703                     1
# 1  140708                     0
# 2  140719                     1
# 3  140720                     1
# 4  140721                     1
