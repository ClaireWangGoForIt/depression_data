# %% [markdown]
# ## Kaggle Competition:<br>
# https://www.kaggle.com/competitions/playground-series-s4e11

# %% [markdown]
# ## Extra Data Sources <br>

# %% [markdown]
# https://worldpopulationreview.com/cities/india<br>
# https://statisticstimes.com/demographics/country/india-cities-population.php

# %% [markdown]
# ## Import Libraries and Load Data

# %%
## import the necessary libraries
import pandas as pd
# Display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Prevent truncation of column contents
pd.set_option('display.max_colwidth', None)
import warnings
warnings.filterwarnings("ignore")

## load the training data
train = pd.read_csv("train.csv")
## load the test data
test = pd.read_csv("test.csv")

# %% [markdown]
# ## Data Preprocessing

# %%
print(train.shape)
print(test.shape)
print(train["Depression"].value_counts())
print(train.columns)
# Out:
# (140700, 20)
# (93800, 19)
# Depression
# 0    115133
# 1     25567
# Name: count, dtype: int64
# Index(['id', 'Name', 'Gender', 'Age', 'City',
#        'Working Professional or Student', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %% [markdown]
# ### split cities into big citeis and small cities

# %%
## load city data
city = pd.read_excel("cities_populations.xlsx")
city = city[city['country'] == 'India'][['city_ascii', 'population']]

## check for missing cities in the city data
missing_cities = pd.Series(train['City'].unique())[~pd.Series(train['City'].unique()).isin(pd.Series(city['city_ascii'].unique()))]
print('These cities in training dataset are missing from the city data:')
print(missing_cities)
print(train[train['City'].isin(missing_cities)].shape)

missing_citiesN = pd.Series(test['City'].unique())[~pd.Series(test['City'].unique()).isin(pd.Series(city['city_ascii'].unique()))]
print('These cities in testing dataset are missing from the city data:')
print(missing_citiesN)
print(test[test['City'].isin(missing_citiesN)].shape)
# Out:
# These cities in training dataset are missing from the city data:
# 30             Ishanabad
# 31                 Vidhi
# 32                 Ayush
# 34               Krishna
# 35             Aishwarya
# 36                Keshav
# 37                Harsha
# 38                Nalini
# 39                Aditya
# 40              Malyansh
# 41           Raghavendra
# 42                Saanvi
# 43                M.Tech
# 44                Bhavna
# 45            Less Delhi
# 46               Nandini
# 47                 M.Com
# 48                 Plata
# 49                Atharv
# 50              Pratyush
# 51                  City
# 52                   3.0
# 53    Less than 5 Kalyan
# 54                   MCA
# 55                  Mira
# 56            Moreadhyay
# 58              Ishkarsh
# 59                 Kashk
# 60                 Mihir
# 61                 Vidya
# 62               Tolkata
# 63                  Anvi
# 64                Krinda
# 65                Ayansh
# 66                 Shrey
# 67                 Ivaan
# 68                Vaanya
# 69                Gaurav
# 70                 Harsh
# 71               Reyansh
# 72               Kashish
# 73                Kibara
# 74             Vaishnavi
# 75                Chhavi
# 76                 Parth
# 77                  Mahi
# 78                Tushar
# 79                   MSc
# 80                    No
# 81                 Rashi
# 82                    ME
# 83               Molkata
# 84            Researcher
# 85                 Kagan
# 86                Armaan
# 87                 Ithal
# 88                Nalyan
# 89                 Dhruv
# 90             Galesabad
# 91                 Itheg
# 92              Aaradhya
# 93                 Pooja
# 94                Khushi
# 95             Khaziabad
# 96                Jhanvi
# 97                Unirar
# dtype: object
# (96, 20)
# These cities in testing dataset are missing from the city data:
# 30               Malyan
# 31             Pratyush
# 32                Vidya
# 33    Less than 5 hours
# 34                Aditi
# 35               Keshav
# 36               Nalini
# 37               Mhopal
# 38                 Avni
# 39                  Ira
# 40            Vaishnavi
# 41               Bhavna
# 42               Lawyer
# 43                Thani
# 44              Hrithik
# 45                 City
# 46                Unaly
# 47            Is Kanpur
# 48              Golkata
# 49           Less Delhi
# 50                 Sara
# 51               Saurav
# 52               Vikram
# 53                Parth
# 54             Siddhesh
# 55               Vaikot
# 56                Leela
# 57              Chemist
# 58      San Vasai-Virar
# 59                   No
# 60           More Delhi
# 61               Saanvi
# 62              Pratham
# 63                Vidhi
# 64              Abhinav
# 65              Rolkata
# 66               Ghopal
# 67                No.12
# dtype: object
# (50, 19)

# %%
## merge the city data with the training data, which also delete the missing cities from the training data(most of them are probably typos)
train = train.merge(city, left_on='City', right_on='city_ascii', how='left')
train.drop(columns=['city_ascii'], inplace=True)
train.rename(columns={'population': 'city_population'}, inplace=True)

## merge the city data with the test data, which also delete the missing cities from the testing data(most of them are probably typos)
test = test.merge(city, left_on='City', right_on='city_ascii', how='left')
test.drop(columns=['city_ascii'], inplace=True)
test.rename(columns={'population': 'city_population'}, inplace=True)

# %%
## split cities based on population with a threshold of 2 million
threshold = 2000000
train['city_type'] = train['city_population'].apply(lambda x: 'big' if x > threshold else 'small')
test['city_type'] = test['city_population'].apply(lambda x: 'big' if x > threshold else 'small')
print(train['city_type'].value_counts())
print(test['city_type'].value_counts())
# Out:
# city_type
# small    82094
# big      78156
# Name: count, dtype: int64
# city_type
# small    55354
# big      51961
# Name: count, dtype: int64

# %% [markdown]
# ### check for outliers in training data

# %%
categories = [
    "Gender",
    "city_type",
    "Working Professional or Student",
    "Profession",
    "Academic Pressure",
    "Work Pressure",
    "Study Satisfaction",
    "Job Satisfaction",
    "Sleep Duration",
    "Dietary Habits",
    "Degree",
    "Have you ever had suicidal thoughts ?",
    "Work/Study Hours",
    "Financial Stress",
    "Family History of Mental Illness",
]
for category in categories:
    print(train[category].value_counts())
# Out:
# Gender
# Male      87682
# Female    72568
# Name: count, dtype: int64
# city_type
# small    82094
# big      78156
# Name: count, dtype: int64
# Working Professional or Student
# Working Professional    127197
# Student                  33053
# Name: count, dtype: int64
# Profession
# Teacher                   28935
# Content Writer             8846
# Architect                  4928
# Consultant                 4689
# HR Manager                 4571
# Pharmacist                 4396
# Doctor                     3561
# Business Analyst           3493
# Entrepreneur               3359
# Chef                       3334
# Chemist                    3269
# Educational Consultant     3179
# Researcher                 2658
# Data Scientist             2635
# Lawyer                     2602
# Customer Support           2304
# Marketing Manager          2223
# Pilot                      2189
# Travel Consultant          2062
# Plumber                    1943
# Manager                    1942
# Sales Executive            1922
# Judge                      1875
# Financial Analyst          1731
# Electrician                1725
# Civil Engineer             1641
# Software Engineer          1628
# UX/UI Designer             1598
# Digital Marketer           1507
# Finanancial Analyst        1481
# Accountant                 1463
# Graphic Designer           1332
# Mechanical Engineer        1297
# Research Analyst            749
# Investment Banker           420
# Student                      10
# Profession                    6
# LLM                           6
# Academic                      5
# Moderate                      4
# B.Ed                          4
# Yogesh                        3
# BCA                           3
# Unemployed                    3
# PhD                           2
# MBA                           2
# BE                            1
# Unveil                        1
# Visakhapatnam                 1
# Pranav                        1
# Analyst                       1
# M.Ed                          1
# Nagpur                        1
# Working Professional          1
# Patna                         1
# MBBS                          1
# B.Com                         1
# Medical Doctor                1
# BBA                           1
# City Manager                  1
# FamilyVirar                   1
# Family Consultant             1
# Dev                           1
# Yuvraj                        1
# Name: count, dtype: int64
# Academic Pressure
# 3.0    8994
# 5.0    7345
# 4.0    5997
# 1.0    5769
# 2.0    4944
# Name: count, dtype: int64
# Work Pressure
# 2.0    27444
# 4.0    25468
# 5.0    25249
# 3.0    24777
# 1.0    24242
# Name: count, dtype: int64
# Study Satisfaction
# 4.0    7532
# 3.0    7050
# 2.0    6842
# 1.0    6352
# 5.0    5273
# Name: count, dtype: int64
# Job Satisfaction
# 2.0    27742
# 5.0    25726
# 1.0    25169
# 3.0    24936
# 4.0    23618
# Name: count, dtype: int64
# Sleep Duration
# Less than 5 hours    44069
# 7-8 hours            42416
# More than 8 hours    37066
# 5-6 hours            36603
# 3-4 hours               12
# 4-5 hours               10
# 6-7 hours                8
# 2-3 hours                8
# No                       7
# 8-9 hours                5
# 4-6 hours                5
# 6-8 hours                4
# 1-6 hours                4
# than 5 hours             4
# Unhealthy                3
# 9-11 hours               2
# 3-6 hours                2
# 10-11 hours              2
# Sleep_Duration           2
# 45                       2
# 9-5                      1
# 10-6 hours               1
# 45-48 hours              1
# Work_Study_Hours         1
# 49 hours                 1
# Pune                     1
# 9-6 hours                1
# 8 hours                  1
# 35-36 hours              1
# Indore                   1
# 1-3 hours                1
# 55-66 hours              1
# Moderate                 1
# 40-45 hours              1
# 1-2 hours                1
# 9-5 hours                1
# Name: count, dtype: int64
# Dietary Habits
# Moderate             56378
# Unhealthy            53236
# Healthy              50602
# More Healthy             5
# Indoor                   4
# Yes                      2
# No                       2
# Mihir                    2
# No Healthy               1
# Class 12                 1
# Male                     1
# Vegas                    1
# M.Tech                   1
# Less Healthy             1
# 1.0                      1
# Electrician              1
# Hormonal                 1
# Less than Healthy        1
# 3                        1
# Gender                   1
# BSc                      1
# Pratham                  1
# 2                        1
# Name: count, dtype: int64
# Degree
# Class 12                16552
# B.Ed                    13264
# B.Arch                  10004
# B.Com                    9065
# M.Ed                     6741
# B.Pharm                  6643
# BCA                      6348
# MCA                      5973
# BSc                      5601
# BBA                      5599
# MSc                      5597
# LLM                      5421
# LLB                      5242
# BHM                      5175
# M.Pharm                  5173
# M.Tech                   5159
# B.Tech                   5028
# MBA                      4316
# BA                       4215
# MD                       3971
# ME                       3950
# BE                       3739
# MHM                      3600
# PhD                      3562
# M.Com                    3488
# MBBS                     3368
# MA                       3306
# B.Sc                        6
# M.Arch                      5
# B                           5
# Bhopal                      5
# LL.Com                      4
# HR Manager                  4
# UX/UI Designer              4
# 0                           4
# LLCom                       4
# Doctor                      4
# Kalyan                      3
# MEd                         3
# M                           3
# BEd                         2
# L.Ed                        2
# M.S                         2
# Nalini                      2
# P.Com                       2
# LLBA                        2
# Mihir                       2
# Degree                      2
# BArch                       2
# MPharm                      2
# Jhanvi                      2
# BPharm                      2
# LL B.Ed                     2
# Entrepreneur                1
# 8.56                        1
# 5.88                        1
# Aarav                       1
# RCA                         1
# LHM                         1
# LLTech                      1
# Lata                        1
# S.Arch                      1
# Marsh                       1
# BB                          1
# HCA                         1
# M_Tech                      1
# B.Student                   1
# Navya                       1
# Mahika                      1
# K.Ed                        1
# B B.Com                     1
# B.3.79                      1
# Mthanya                     1
# LCA                         1
# Working Professional        1
# Esha                        1
# LLS                         1
# N.Pharm                     1
# E.Tech                      1
# LLEd                        1
# Pihu                        1
# Vrinda                      1
# 24                          1
# Bhavesh                     1
# MPA                         1
# BH                          1
# Veda                        1
# S.Tech                      1
# 20                          1
# Class 11                    1
# H_Pharm                     1
# Business Analyst            1
# Data Scientist              1
# P.Pharm                     1
# Unite                       1
# Badhya                      1
# S.Pharm                     1
# M. Business Analyst         1
# 29                          1
# CGPA                        1
# MTech                       1
# Vivaan                      1
# BPA                         1
# Plumber                     1
# 5.61                        1
# Brit                        1
# B.03                        1
# Ritik                       1
# 5.56                        1
# B BA                        1
# 7.06                        1
# B.B.Arch                    1
# ACA                         1
# Brithika                    1
# Advait                      1
# Name: count, dtype: int64
# Have you ever had suicidal thoughts ?
# No     80595
# Yes    79655
# Name: count, dtype: int64
# Work/Study Hours
# 10.0    16098
# 11.0    14671
# 9.0     14450
# 0.0     13609
# 12.0    13142
# 2.0     12092
# 6.0     11865
# 7.0     11314
# 1.0     11164
# 3.0     10764
# 5.0     10456
# 8.0     10323
# 4.0     10302
# Name: count, dtype: int64
# Financial Stress
# 2.0    35444
# 5.0    32351
# 4.0    31821
# 1.0    31081
# 3.0    29549
# Name: count, dtype: int64
# Family History of Mental Illness
# No     80206
# Yes    80044
# Name: count, dtype: int64

# %%
## deal with outliers in Profession column(probably typos)
# Get the counts of each profession
profession_counts = train['Profession'].value_counts()
# Filter out professions with fewer than 12 occurrences
valid_professions = profession_counts[profession_counts >= 12].index
# Keep only rows with valid professions
print('Removed professions with fewer than 12 rows')
train = train[train['Profession'].isin(valid_professions) | train['Profession'].isna()]

## deal with outliers in Sleep Duration column(probably typos)
# Get the counts of each Sleep Duration
sleep_duration_counts = train['Sleep Duration'].value_counts()
# Filter out Sleep Duration with fewer than 15 occurrences
valid_sleep_durations = sleep_duration_counts[sleep_duration_counts >= 15].index
# Keep only rows with valid Sleep Duration
print('Removed Sleep Duration with fewer than 15 rows')
train = train[train['Sleep Duration'].isin(valid_sleep_durations) | train['Sleep Duration'].isna()]

## deal with outliers in Dietary Habits column(probably typos)
# Get the counts of each Dietary Habit
Dietary_Habits_counts = train['Dietary Habits'].value_counts()
# Filter out Dietary Habit with fewer than 15 occurrences
valid_Dietary_Habits_counts = Dietary_Habits_counts[Dietary_Habits_counts >= 15].index
# Keep only rows with valid Dietary Habit
print('Removed Dietary Habit with fewer than 15 rows')
train = train[train['Dietary Habits'].isin(valid_Dietary_Habits_counts) | train['Dietary Habits'].isna()]

## deal with outliers in Degrees column(probably typos)
# Get the counts of each Degree
Degree_counts = train['Degree'].value_counts()
# Filter out Degree with fewer than 10 occurrences
valid_Degree_counts = Degree_counts[Degree_counts >= 10].index
# Keep only rows with valid Degree
print('Removed Degree with fewer than 10 rows')
train = train[train['Degree'].isin(valid_Degree_counts) | train['Degree'].isna()]

## check again
categories = [
    "Gender",
    "city_type",
    "Working Professional or Student",
    "Profession",
    "Academic Pressure",
    "Work Pressure",
    "Study Satisfaction",
    "Job Satisfaction",
    "Sleep Duration",
    "Dietary Habits",
    "Degree",
    "Have you ever had suicidal thoughts ?",
    "Work/Study Hours",
    "Financial Stress",
    "Family History of Mental Illness",
]
for category in categories:
    print(train[category].value_counts())
# Out:
# Removed professions with fewer than 12 rows
# Removed Sleep Duration with fewer than 15 rows
# Removed Dietary Habit with fewer than 15 rows
# Removed Degree with fewer than 10 rows
# Gender
# Male      87494
# Female    72423
# Name: count, dtype: int64
# city_type
# small    81899
# big      78018
# Name: count, dtype: int64
# Working Professional or Student
# Working Professional    126946
# Student                  32971
# Name: count, dtype: int64
# Profession
# Teacher                   28898
# Content Writer             8837
# Architect                  4920
# Consultant                 4678
# HR Manager                 4559
# Pharmacist                 4387
# Doctor                     3552
# Business Analyst           3485
# Entrepreneur               3356
# Chef                       3332
# Chemist                    3263
# Educational Consultant     3174
# Researcher                 2654
# Data Scientist             2632
# Lawyer                     2592
# Customer Support           2303
# Marketing Manager          2222
# Pilot                      2188
# Travel Consultant          2062
# Manager                    1940
# Plumber                    1937
# Sales Executive            1921
# Judge                      1872
# Financial Analyst          1727
# Electrician                1722
# Civil Engineer             1638
# Software Engineer          1627
# UX/UI Designer             1594
# Digital Marketer           1503
# Finanancial Analyst        1480
# Accountant                 1461
# Graphic Designer           1329
# Mechanical Engineer        1295
# Research Analyst            748
# Investment Banker           420
# Name: count, dtype: int64
# Academic Pressure
# 3.0    8970
# 5.0    7334
# 4.0    5983
# 1.0    5756
# 2.0    4924
# Name: count, dtype: int64
# Work Pressure
# 2.0    27385
# 4.0    25418
# 5.0    25214
# 3.0    24720
# 1.0    24192
# Name: count, dtype: int64
# Study Satisfaction
# 4.0    7505
# 3.0    7034
# 2.0    6830
# 1.0    6337
# 5.0    5261
# Name: count, dtype: int64
# Job Satisfaction
# 2.0    27683
# 5.0    25684
# 1.0    25121
# 3.0    24887
# 4.0    23565
# Name: count, dtype: int64
# Sleep Duration
# Less than 5 hours    44000
# 7-8 hours            42355
# More than 8 hours    37020
# 5-6 hours            36542
# Name: count, dtype: int64
# Dietary Habits
# Moderate     56259
# Unhealthy    53130
# Healthy      50524
# Name: count, dtype: int64
# Degree
# Class 12    16548
# B.Ed        13257
# B.Arch      10002
# B.Com        9051
# M.Ed         6733
# B.Pharm      6637
# BCA          6341
# MCA          5960
# BBA          5593
# MSc          5591
# BSc          5584
# LLM          5407
# LLB          5234
# BHM          5175
# M.Pharm      5171
# M.Tech       5154
# B.Tech       5027
# MBA          4308
# BA           4206
# MD           3964
# ME           3944
# BE           3729
# MHM          3596
# PhD          3553
# M.Com        3481
# MBBS         3359
# MA           3304
# Name: count, dtype: int64
# Have you ever had suicidal thoughts ?
# No     80429
# Yes    79488
# Name: count, dtype: int64
# Work/Study Hours
# 10.0    16053
# 11.0    14641
# 9.0     14430
# 0.0     13584
# 12.0    13114
# 2.0     12068
# 6.0     11838
# 7.0     11294
# 1.0     11140
# 3.0     10730
# 5.0     10435
# 8.0     10306
# 4.0     10284
# Name: count, dtype: int64
# Financial Stress
# 2.0    35389
# 5.0    32285
# 4.0    31758
# 1.0    31005
# 3.0    29476
# Name: count, dtype: int64
# Family History of Mental Illness
# No     80035
# Yes    79882
# Name: count, dtype: int64

# %% [markdown]
# ### check for outliers in test data

# %%
## check possible values for possible categorical columns
categories = [
    "Gender",
    "city_type",
    "Working Professional or Student",
    "Profession",
    "Academic Pressure",
    "Work Pressure",
    "Study Satisfaction",
    "Job Satisfaction",
    "Sleep Duration",
    "Dietary Habits",
    "Degree",
    "Have you ever had suicidal thoughts ?",
    "Work/Study Hours",
    "Financial Stress",
    "Family History of Mental Illness",
]
outlier_tests = pd.DataFrame()
for category in categories:
    test_unique = pd.Series(test[category].unique())  # Convert to Series
    train_unique = pd.Series(train[category].unique())  # Convert to Series
    if len(test_unique[~test_unique.isin(train_unique)]) > 0:
        print(category)
        outlier_test = test[
            test[category].isin(test_unique[~test_unique.isin(train_unique)])
        ]
        print(len(outlier_test))
        print(outlier_test)
        outlier_tests = pd.concat([outlier_tests, outlier_test])
        print("\n")
# Get unique rows of the DataFrame
outlier_tests = outlier_tests.drop_duplicates()
print(outlier_tests)
print(outlier_tests.shape)
# Out:
# Profession
# 50
#            id         Name  Gender   Age           City  \
# 561    141166          Dev    Male  44.0         Meerut
# 1467   141952        Pooja  Female  47.0         Meerut
# 2429   142797       Prachi  Female  18.0        Chennai
# 2847   143165        Anand    Male  26.0       Srinagar
# 2848   143165        Anand    Male  26.0       Srinagar
# 2849   143165        Anand    Male  26.0       Srinagar
# 2850   143165        Anand    Male  26.0       Srinagar
# 17292  155969          Ira  Female  30.0           Agra
# 20115  158433        Pooja  Female  35.0       Varanasi
# 25030  162654       Shivam    Male  49.0         Rajkot
# 29716  166722     Siddhesh    Male  42.0         Nagpur
# 31915  168672        Shrey    Male  21.0      Hyderabad
# 32535  169179          Ira  Female  48.0      Hyderabad
# 33445  169985       Yogesh    Male  28.0         Nashik
# 35356  171693       Prachi    Male  27.0       Vadodara
# 40559  176256     Pratyush    Male  48.0      Faridabad
# 43446  178791       Advait    Male  54.0          Surat
# 44088  179362       Ritvik    Male  44.0           Agra
# 44395  179624        Kunal    Male  47.0         Nashik
# 46293  181298       Harsha    Male  44.0         Rajkot
# 47662  182463       Ishita  Female  46.0         Kanpur
# 95325            Working Professional                Unveil
# 96047            Working Professional       City Consultant
# 98230            Working Professional               M.Pharm
#
#        Academic Pressure  Work Pressure   CGPA  Study Satisfaction  \
# 561                  NaN            5.0    NaN                 NaN
# 1467                 NaN            2.0    NaN                 NaN
# 2429                 NaN            2.0    NaN                 NaN
# 2847                 NaN            3.0    NaN                 NaN
# 2848                 NaN            3.0    NaN                 NaN
# 2849                 NaN            3.0    NaN                 NaN
# 2850                 NaN            3.0    NaN                 NaN
# 17292                5.0            NaN  10.00                 2.0
# 20115                NaN            1.0    NaN                 NaN
# 25030                NaN            5.0    NaN                 NaN
# 29716                NaN            3.0    NaN                 NaN
# 31915                NaN            3.0    NaN                 NaN
# 32535                NaN            3.0    NaN                 NaN
# 33445                NaN            4.0    NaN                 NaN
# 35356                NaN            4.0    NaN                 NaN
# 40559                NaN            5.0    NaN                 NaN
# 43446                NaN            1.0    NaN                 NaN
# 44088                NaN            4.0    NaN                 NaN
# 44395                NaN            3.0    NaN                 NaN
# 46293                NaN            5.0    NaN                 NaN
# 47662                NaN            3.0    NaN                 NaN
# 49831                NaN            5.0    NaN                 NaN
# 53565                NaN            4.0    NaN                 NaN
# 53837                NaN            4.0    NaN                 NaN
# 56516                NaN            3.0    NaN                 NaN
# 59957                NaN            3.0    NaN                 NaN
# 60122                NaN            5.0    NaN                 NaN
# 60565                NaN            4.0    NaN                 NaN
# 61194                NaN            1.0    NaN                 NaN
# 62681                NaN            4.0    NaN                 NaN
# 65668                NaN            5.0    NaN                 NaN
# 69001                NaN            5.0    NaN                 NaN
# 69497                NaN            5.0    NaN                 NaN
# 70728                NaN            3.0    NaN                 NaN
# 71438                3.0            NaN   7.24                 5.0
# 74340                NaN            5.0    NaN                 NaN
# 74341                NaN            5.0    NaN                 NaN
# 74342                NaN            5.0    NaN                 NaN
# 74343                NaN            5.0    NaN                 NaN
# 74599                NaN            4.0    NaN                 NaN
# 76036                NaN            3.0    NaN                 NaN
# 76406                1.0            NaN   7.08                 5.0
# 79055                NaN            2.0    NaN                 NaN
# 81632                NaN            5.0    NaN                 NaN
# 82939                NaN            5.0    NaN                 NaN
# 83349                NaN            5.0    NaN                 NaN
# 91221                4.0            NaN   8.50                 5.0
# 95325                NaN            5.0    NaN                 NaN
# 96047                NaN            2.0    NaN                 NaN
# 98230                NaN            2.0    NaN                 NaN
#
#        Job Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 561                 3.0          5-6 hours      Unhealthy      M.Ed
# 1467                2.0          5-6 hours        Healthy      B.Ed
# 2429                5.0          7-8 hours        Healthy  Class 12
# 2847                1.0          7-8 hours       Moderate       MCA
# 2848                1.0          7-8 hours       Moderate       MCA
# 2849                1.0          7-8 hours       Moderate       MCA
# 2850                1.0          7-8 hours       Moderate       MCA
# 17292               NaN  Less than 5 hours      Unhealthy    M.Tech
# 20115               3.0          7-8 hours      Unhealthy        BE
# 25030               4.0  More than 8 hours      Unhealthy       PhD
# 29716               3.0  More than 8 hours        Healthy   M.Pharm
# 31915               1.0          5-6 hours      Unhealthy       BCA
# 32535               5.0          5-6 hours        Healthy     B.Com
# 33445               1.0  Less than 5 hours        Healthy        MA
# 35356               1.0  Less than 5 hours      Unhealthy     B.Com
# 40559               3.0  Less than 5 hours       Moderate     B.Com
# 43446               1.0  Less than 5 hours       Moderate       MSc
# 44088               4.0          5-6 hours        Healthy    B.Tech
# 44395               4.0          5-6 hours        Healthy       MCA
# 46293               4.0  More than 8 hours        Healthy        MD
# 47662               2.0  Less than 5 hours        Healthy       LLB
# 49831               4.0          5-6 hours      Unhealthy       BSc
# 53565               2.0          7-8 hours       Moderate       BCA
# 53837               5.0          5-6 hours       Moderate       BSc
# 56516               5.0  More than 8 hours       Moderate       BBA
# 59957               4.0  More than 8 hours       Moderate      M.Ed
# 60122               5.0          7-8 hours      Unhealthy       MBA
# 60565               4.0  Less than 5 hours        Healthy       BCA
# 61194               2.0  More than 8 hours      Unhealthy       MCA
# 62681               4.0  More than 8 hours      Unhealthy      B.Ed
# 65668               2.0          5-6 hours      Unhealthy        MD
# 69001               4.0  More than 8 hours       Moderate       BHM
# 69497               1.0  Less than 5 hours      Unhealthy      M.Ed
# 70728               1.0  Less than 5 hours        Healthy       BSc
# 71438               NaN  More than 8 hours        Healthy       MCA
# 74340               3.0  More than 8 hours        Healthy  Class 12
# 74341               3.0  More than 8 hours        Healthy  Class 12
# 74342               3.0  More than 8 hours        Healthy  Class 12
# 74343               3.0  More than 8 hours        Healthy  Class 12
# 74599               3.0          7-8 hours       Moderate        MD
# 76036               1.0  Less than 5 hours        Healthy    B.Tech
# 76406               NaN          7-8 hours      Unhealthy       MCA
# 79055               2.0          5-6 hours      Unhealthy       LLB
# 81632               4.0          7-8 hours       Moderate      MBBS
# 82939               2.0  More than 8 hours      Unhealthy       PhD
# 83349               5.0  Less than 5 hours      Unhealthy       BSc
# 91221               NaN          7-8 hours        Healthy  Class 12
# 95325               1.0          7-8 hours        Healthy   M.Pharm
# 96047               1.0  Less than 5 hours       Moderate       BSc
# 98230               2.0          5-6 hours      Unhealthy   M.Pharm
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 561                                      No               8.0
# 1467                                     No               2.0
# 2429                                    Yes               6.0
# 2847                                     No               1.0
# 2848                                     No               1.0
# 2849                                     No               1.0
# 2850                                     No               1.0
# 17292                                   Yes               5.0
# 20115                                   Yes               3.0
# 25030                                    No               9.0
# 29716                                    No               1.0
# 31915                                    No              12.0
# 32535                                    No               7.0
# 33445                                   Yes              11.0
# 35356                                   Yes               4.0
# 40559                                    No               6.0
# 43446                                    No               2.0
# 44088                                   Yes               9.0
# 44395                                   Yes              11.0
# 46293                                    No               5.0
# 47662                                   Yes               8.0
# 49831                                   Yes              10.0
# 53565                                    No              12.0
# 53837                                   Yes               9.0
# 56516                                    No               6.0
# 59957                                    No               5.0
# 60122                                   Yes               5.0
# 60565                                    No               8.0
# 61194                                    No              12.0
# 62681                                    No               9.0
# 65668                                   Yes              10.0
# 69001                                   Yes               3.0
# 69497                                   Yes               2.0
# 70728                                    No               5.0
# 71438                                    No               4.0
academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 618                   NaN            1.0   NaN                 NaN
# 4128                  NaN            4.0   NaN                 NaN
# 5279                  NaN            1.0   NaN                 NaN
# 10129                 NaN            3.0   NaN                 NaN
# 14558                 3.0            NaN  9.97                 1.0
# 17670                 NaN            4.0   NaN                 NaN
# 18585                 NaN            4.0   NaN                 NaN
# 18586                 NaN            4.0   NaN                 NaN
# 18587                 NaN            4.0   NaN                 NaN
# 18588                 NaN            4.0   NaN                 NaN
# 18988                 NaN            3.0   NaN                 NaN
# 21637                 1.0            NaN  8.63                 5.0
# 21716                 NaN            4.0   NaN                 NaN
# 23482                 NaN            5.0   NaN                 NaN
# 24832                 4.0            NaN  6.02                 2.0
# 25262                 NaN            4.0   NaN                 NaN
# 25263                 NaN            2.0   NaN                 NaN
# 30404                 2.0            NaN  8.21                 4.0
# 30551                 NaN            1.0   NaN                 NaN
# 31005                 NaN            1.0   NaN                 NaN
# 33489                 NaN            5.0   NaN                 NaN
# 33941                 NaN            4.0   NaN                 NaN
# 34090                 NaN            4.0   NaN                 NaN
# 36880                 3.0            NaN  7.88                 1.0
# 38107                 2.0            NaN  7.79                 5.0
# 39812                 NaN            2.0   NaN                 NaN
# 39813                 NaN            2.0   NaN                 NaN
# 39814                 NaN            2.0   NaN                 NaN
# 39815                 NaN            2.0   NaN                 NaN
# 41257                 NaN            1.0   NaN                 NaN
# 42809                 NaN            1.0   NaN                 NaN
# 43369                 NaN            5.0   NaN                 NaN
# 43370                 NaN            5.0   NaN                 NaN
# 45833                 NaN            2.0   NaN                 NaN
# 46208                 NaN            2.0   NaN                 NaN
# 47091                 NaN            4.0   NaN                 NaN
# 47722                 NaN            4.0   NaN                 NaN
# 52026                 NaN            4.0   NaN                 NaN
# 54544                 NaN            4.0   NaN                 NaN
# 54545                 NaN            4.0   NaN                 NaN
# 54546                 NaN            4.0   NaN                 NaN
# 54547                 NaN            4.0   NaN                 NaN
# 54926                 NaN            4.0   NaN                 NaN
# 58062                 NaN            1.0   NaN                 NaN
# 58773                 NaN            5.0   NaN                 NaN
# 59650                 NaN            5.0   NaN                 NaN
# 61803                 5.0            NaN  6.42                 2.0
# 61804                 5.0            NaN  6.42                 2.0
# 61805                 5.0            NaN  6.42                 2.0
# 61806                 5.0            NaN  6.42                 2.0
# 66352                 NaN            2.0   NaN                 NaN
# 67126                 NaN            4.0   NaN                 NaN
# 70127                 NaN            2.0   NaN                 NaN
# 70859                 NaN            2.0   NaN                 NaN
# 76735                 NaN            2.0   NaN                 NaN
# 77352                 NaN            1.0   NaN                 NaN
# 77353                 NaN            1.0   NaN                 NaN
# 77354                 NaN            1.0   NaN                 NaN
# 77355                 NaN            1.0   NaN                 NaN
# 78899                 NaN            3.0   NaN                 NaN
# 79407                 NaN            3.0   NaN                 NaN
# 79844                 NaN            2.0   NaN                 NaN
# 77355                5.0                           9-11 hours        Healthy
# 78899                2.0                           9-10 hours        Healthy
# 79407                5.0                            3-6 hours      Unhealthy
# 79844                1.0                            8-9 hours      Unhealthy
# 81563                5.0                            4-5 hours      Unhealthy
# 83128                NaN                            4-5 hours       Moderate
# 85922                2.0                            2-3 hours      Unhealthy
# 87099                NaN                            1-6 hours       Moderate
# 87412                5.0                            9-5 hours       Moderate
# 100036               5.0                            4-5 hours      Unhealthy
# 100163               NaN                            2-3 hours       Moderate
# 101317               3.0                            8-9 hours        Healthy
#
#           Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 618          LLM                                    No               1.0
# 4128         PhD                                    No               0.0
# 5279          BE                                   Yes               5.0
# 10129       M.Ed                                    No               0.0
# 14558        BSc                                   Yes               0.0
# 17670        BSc                                   Yes               6.0
# 18585        BSc                                   Yes               6.0
# 18586        BSc                                   Yes               6.0
# 18587        BSc                                   Yes               6.0
# 18588        BSc                                   Yes               6.0
# 18988         MA                                   Yes              12.0
# 21637   Class 12                                   Yes               7.0
# 21716   Class 12                                    No               0.0
# 23482       MBBS                                   Yes              11.0
# 24832     B.Arch                                   Yes              11.0
# 25262        MBA                                   Yes               3.0
# 25263         MA                                   Yes               3.0
# 30404   Class 12                                   Yes               8.0
# 30551        LLB                                   Yes              11.0
# 31005        PhD                                   Yes              12.0
# 33489   Class 12                                   Yes              11.0
# 33941         BA                                   Yes               2.0
# 34090       B.Ed                                   Yes               7.0
# 36880        BHM                                   Yes              10.0
# 38107   Class 12                                    No               1.0
# 39812       B.Ed                                   Yes               9.0
# 39813       B.Ed                                   Yes               9.0
# 39814       B.Ed                                   Yes               9.0
# 39815       B.Ed                                   Yes               9.0
# 41257    M.Pharm                                   Yes               5.0
# 42809       B.Ed                                    No               3.0
# 43369     M.Tech                                    No               1.0
# 43370     M.Tech                                    No               1.0
# 45833         BE                                    No               6.0
# 46208        MBA                                   Yes               3.0
# 47091        LLM                                   Yes              10.0
# 47722        BBA                                   Yes              11.0
# 52026         BA                                   Yes               3.0
# 54544      M.Com                                   Yes               1.0
# 54545      M.Com                                   Yes               1.0
# 54546      M.Com                                   Yes               1.0
# 54547      M.Com                                   Yes               1.0
# 54926        LLM                                    No               0.0
# 58062      B.Com                                   Yes               1.0
# 58773        BHM                                    No               9.0
# 59650        BBA                                   Yes               1.0
# 61803         BA                                   Yes              11.0
# 61804         BA                                   Yes              11.0
# 61805         BA                                   Yes              11.0
# 61806         BA                                   Yes              11.0
# 66352         ME                                    No               2.0
# 67126        LLM                                   Yes               5.0
# 70127    M.Pharm                                   Yes               7.0
# 70859    B.Pharm                                    No               4.0
# 76735        MBA                                   Yes               8.0
# 77352        BSc                                   Yes               2.0
# 77353        BSc                                   Yes               2.0
# 77354        BSc                                   Yes               2.0
# 77355        BSc                                   Yes               2.0
# 78899         BA                                    No               3.0
# 79407        MHM                                    No               5.0
# 79844       B.Ed                                   Yes               7.0
# 81563        BSc                                   Yes              10.0
# 83128       B.Ed                                    No              12.0
# 85922       MBBS                                   Yes              10.0
# 53587         1798218.0     small
# 56217         1618879.0     small
# 56496         1198491.0     small
# 60104         8009000.0       big
# 61811         1180570.0     small
# 61812           37911.0     small
# 61813           14454.0     small
# 61814           12167.0     small
# 62456        24973000.0       big
# 62956         1180570.0     small
# 62957           37911.0     small
# 62958           14454.0     small
# 62959           12167.0     small
# 63291         1486053.0     small
# 64407         1414050.0     small
# 64586         2065771.0       big
# 68764         1198491.0     small
# 69627         6538000.0       big
# 69793         2405665.0       big
# 69959         1618879.0     small
# 69962         1486053.0     small
# 71058         1486053.0     small
# 71418         1198491.0     small
# 73021         2405665.0       big
# 77262         6538000.0       big
# 77448         2043000.0       big
# 78243         1198491.0     small
# 79786         3382000.0       big
# 83127         1684222.0     small
# 83278         3382000.0       big
# 83987         1198491.0     small
# 86227         2375820.0       big
# 88157         2065771.0       big
# 88381         2035922.0       big
# 93531         1246381.0     small
# 93842        18502000.0       big
# 94216         1684222.0     small
# 99517         1221233.0     small
# 100279        2405665.0       big
# 100815        1305429.0     small
# 100966       12395000.0       big
# 102107              NaN     small
# 103040        1221233.0     small
# 103166        2043000.0       big
# 103377        2035922.0       big
# 104441       18502000.0       big
# 105008        1585704.0     small
# 105482        6538000.0       big
# (245, 21)

# %% [markdown]
# finding: 245 rows in test data have values that are not included in train data for some columns(probably because of typos)<br>
# following step: use the most frequent value in train data for these rows

# %% [markdown]
# ### use the most frequent value in train data for these outlier rows

# %%
# Loop through each category to identify and handle outliers
for category in categories:
    # Get unique values for the category in test and train datasets
    test_unique = pd.Series(test[category].unique())  # Convert to Series
    train_unique = pd.Series(train[category].unique())  # Convert to Series

    # Identify outlier values (present in test but not in train)
    unmatched_values = test_unique[~test_unique.isin(train_unique)]

    # Check if there are any outliers
    if len(unmatched_values) > 0:
        outliers_count = len(test[test[category].isin(unmatched_values)])

        print(f"{outliers_count} Outliers found in category: {category}")

        # Get the mode (most frequent value) for the category in train
        most_frequent_value = train[category].mode()[
            0
        ]  # Mode always returns a Series, take the first value

        # Replace the outlier values in test data with the most frequent value from train
        test.loc[test[category].isin(unmatched_values), category] = most_frequent_value

        print(
            f"Replaced outlier values in category '{category}' with '{most_frequent_value}'\n"
        )
# Out:
# 50 Outliers found in category: Profession
# Replaced outlier values in category 'Profession' with 'Teacher'
#
# 70 Outliers found in category: Sleep Duration
# Replaced outlier values in category 'Sleep Duration' with 'Less than 5 hours'
#
# 31 Outliers found in category: Dietary Habits
# Replaced outlier values in category 'Dietary Habits' with 'Moderate'
#
# 94 Outliers found in category: Degree
# Replaced outlier values in category 'Degree' with 'Class 12'

# %% [markdown]
# ### check for NAs

# %%
## split data based on Working Professional or Student
train_student = train[train["Working Professional or Student"] == "Student"]
train_professional = train[
    train["Working Professional or Student"] == "Working Professional"
]
test_student = test[test["Working Professional or Student"] == "Student"]
test_professional = test[
    test["Working Professional or Student"] == "Working Professional"
]

# Define the columns to process for each DataFrame
train_student_na_columns = ["Academic Pressure", "CGPA", "Study Satisfaction", "Dietary Habits", "Financial Stress"]
train_professional_na_columns = ["Work Pressure", "Job Satisfaction", "Profession", "Dietary Habits", "Degree", "Financial Stress"]
test_student_na_columns = ["Academic Pressure", "CGPA", "Study Satisfaction", "Dietary Habits", "Degree"]
test_professional_na_columns = ["Work Pressure", "Job Satisfaction", "Profession", "Dietary Habits", "Degree"]

# Replace missing values in train_student for the listed columns
for col in train_student_na_columns:
    train_student.loc[:, col] = train_student[col].fillna(train_student[col].mode()[0])

# Replace missing values in train_professional for the listed columns
for col in train_professional_na_columns:
    train_professional.loc[:, col] = train_professional[col].fillna(train_professional[col].mode()[0])

# Replace missing values in test_student for the listed columns
for col in test_student_na_columns:
    test_student.loc[:, col] = test_student[col].fillna(test_student[col].mode()[0])

# Replace missing values in test_professional for the listed columns
for col in test_professional_na_columns:
    test_professional.loc[:, col] = test_professional[col].fillna(test_professional[col].mode()[0])

# check nas in updated DataFrames
print("Updated train_student:")
print(train_student.isna().sum())

print("\nUpdated train_professional:")
print(train_professional.isna().sum())

print("\nUpdated test_student:")
print(test_student.isna().sum())

print("\nUpdated test_professional:")
print(test_professional.isna().sum())
# Out:
# Updated train_student:
# id                                           0
# Name                                         0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                               32938
# Academic Pressure                            0
# Work Pressure                            32968
# CGPA                                         0
# Study Satisfaction                           0
# Job Satisfaction                         32960
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# Depression                                   0
# city_population                             26
# city_type                                    0
# dtype: int64
#
# Updated train_professional:
# id                                            0
# Name                                          0
# Gender                                        0
# Age                                           0
# City                                          0
# Working Professional or Student               0
# Profession                                    0
# Academic Pressure                        126941
# Work Pressure                                 0
# CGPA                                     126940
# Study Satisfaction                       126940
# Job Satisfaction                              0
# Sleep Duration                                0
# Dietary Habits                                0
# Degree                                        0
# Have you ever had suicidal thoughts ?         0
# Work/Study Hours                              0
# Financial Stress                              0
# Family History of Mental Illness              0
# Depression                                    0
# city_population                              69
# city_type                                     0
# dtype: int64
#
# Updated test_student:
# id                                           0
# Name                                         0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                               22390
# Academic Pressure                            0
# Work Pressure                            22415
# CGPA                                         0
# Study Satisfaction                           0
# Job Satisfaction                         22408
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# city_population                             11
# city_type                                    0
# dtype: int64
#
# Updated test_professional:
# id                                           0
# Name                                         0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                                   0
# Academic Pressure                        84891
# Work Pressure                                0
# CGPA                                     84890
# Study Satisfaction                       84890
# Job Satisfaction                             0
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# city_population                             39
# city_type                                    0
# dtype: int64

# %% [markdown]
# ### combine data

# %%
train_new = pd.concat([train_student, train_professional])
test_new = pd.concat([test_student, test_professional])
print(train.shape)
print(test.shape)
print(train_new.shape)
print(test_new.shape)
print(train_new.head())
print(test_new.head())
train_new.to_csv("train_new.csv", index=False)
test_new.to_csv("test_new.csv", index=False)
# Out:
# (159917, 22)
# (107315, 21)
# (159917, 22)
# (107315, 21)
#     id       Name  Gender   Age           City  \
# 2    2     Yuvraj    Male  33.0  Visakhapatnam
# 8    8  Aishwarya  Female  24.0      Bangalore
# 27  26     Aditya    Male  31.0       Srinagar
# 28  26     Aditya    Male  31.0       Srinagar
# 29  26     Aditya    Male  31.0       Srinagar
#
#    Working Professional or Student Profession  Academic Pressure  \
# 2                          Student        NaN                5.0
# 8                          Student        NaN                2.0
# 27                         Student        NaN                3.0
# 28                         Student        NaN                3.0
# 29                         Student        NaN                3.0
#
#     Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 2             NaN  8.97                 2.0               NaN
# 8             NaN  5.90                 5.0               NaN
# 27            NaN  7.03                 5.0               NaN
# 28            NaN  7.03                 5.0               NaN
# 29            NaN  7.03                 5.0               NaN
#
#        Sleep Duration Dietary Habits   Degree  \
# 2           5-6 hours        Healthy  B.Pharm
# 8           5-6 hours       Moderate      BSc
# 27  Less than 5 hours        Healthy       BA
# 28  Less than 5 hours        Healthy       BA
# 29  Less than 5 hours        Healthy       BA
#
#    Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 2                                    Yes               3.0               1.0
# 8                                     No               3.0               2.0
# 27                                    No               9.0               1.0
# 28                                    No               9.0               1.0
# 29                                    No               9.0               1.0
#
#    Family History of Mental Illness  Depression  city_population city_type
# 2                                No           1        2035922.0       big
# 8                               Yes           0       15386000.0       big
# 27                              Yes           0        1180570.0     small
# 28                              Yes           0          37911.0     small
# 29                              Yes           0          14454.0     small
#         id    Name  Gender   Age           City  \
# 4   140703  Nalini  Female  23.0         Rajkot
# 9   140708   Navya  Female  21.0          Surat
# 27  140719   Kiran    Male  28.0        Lucknow
# 28  140720   Rashi  Female  26.0      Ghaziabad
# 29  140721   Manan    Male  32.0  Visakhapatnam
#
#    Working Professional or Student Profession  Academic Pressure  \
# 4                          Student        NaN                5.0
# 9                          Student        NaN                1.0
# 27                         Student        NaN                5.0
# 28                         Student        NaN                3.0
# 29                         Student        NaN                3.0
#
#     Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 4             NaN  6.84                 1.0               NaN
# 9             NaN  7.39                 3.0               NaN
# 27            NaN  6.03                 3.0               NaN
# 28            NaN  8.63                 5.0               NaN
# 29            NaN  8.61                 1.0               NaN
#
#        Sleep Duration Dietary Habits Degree  \
# 4   More than 8 hours       Moderate    BSc
# 9   Less than 5 hours        Healthy    BBA
# 27          7-8 hours       Moderate     MA
# 28  More than 8 hours       Moderate    BBA
# 29  Less than 5 hours       Moderate   M.Ed
#
#    Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 4                                    Yes              10.0               4.0
# 9                                     No               8.0               1.0
# 27                                    No              11.0               3.0
# 28                                   Yes              10.0               4.0
# 29                                   Yes              11.0               5.0
#
#    Family History of Mental Illness  city_population city_type
# 4                                No        2043000.0       big
# 9                               Yes        6538000.0       big
# 27                              Yes        3382000.0       big
# 28                              Yes        2375820.0       big
# 29                               No        2035922.0       big

# %% [markdown]
# ## Build Basic Model

# %%
print(train_student["Depression"].value_counts())
# Out:
# Depression
# 1    19126
# 0    13845
# Name: count, dtype: int64

# %%
print(train_professional["Depression"].value_counts())
# Out:
# Depression
# 0    116559
# 1     10387
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from category_encoders import TargetEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

def preprocess_data(train_data, test_data, features, target_column):
    """
    Preprocesses the train and test data:
    - Selects specific features
    - Encodes categorical variables
    """
    # Select specified features
    X_train = train_data[features]
    y_train = train_data[target_column]
    X_test = test_data[features]

    # Encode categorical variables using Target Encoding
    categorical_cols = X_train.select_dtypes(include=['object']).columns
    encoder = TargetEncoder(cols=categorical_cols)
    X_train_encoded = encoder.fit_transform(X_train, y_train)
    X_test_encoded = encoder.transform(X_test)

    return X_train_encoded, y_train, X_test_encoded

def train_and_predict(X_train, y_train, X_test, output_column_name):
    """
    Trains a stacking classifier and makes predictions on the test data.
    """
    # Train-test split for validation
    X_train_split, X_val, y_train_split, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

    # Define base models
    base_models = [
        ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
        ('gb', GradientBoostingClassifier(n_estimators=100, random_state=42))
    ]

    # Define meta-model
    meta_model = LogisticRegression()

    # Build stacking classifier
    stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5)
    stacking_clf.fit(X_train_split, y_train_split)

    # Validate the model
    y_val_pred = stacking_clf.predict(X_val)
    accuracy = accuracy_score(y_val, y_val_pred)
    print(f"Validation Accuracy ({output_column_name}): {accuracy:.2f}")

    # Predict on the test data
    predictions = stacking_clf.predict(X_test)

    return predictions

# Features for student and professional models
student_features = [
    'Gender', 'Age', 'city_type', 'Academic Pressure', 'CGPA', 'Study Satisfaction', 'Sleep Duration', 
    'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 
    'Financial Stress', 'Family History of Mental Illness'
]
professional_features = [
    'Gender', 'Age', 'city_type', 'Profession', 'Work Pressure', 'Job Satisfaction', 'Sleep Duration', 
    'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 
    'Financial Stress', 'Family History of Mental Illness'
]

# Preprocess and train models
if __name__ == "__main__":
    # Train on train_student and predict on test_student
    X_train_student, y_train_student, X_test_student = preprocess_data(train_student, test_student, student_features, 'Depression')
    student_predictions = train_and_predict(X_train_student, y_train_student, X_test_student, 'Student')

    # Train on train_professional and predict on test_professional
    X_train_professional, y_train_professional, X_test_professional = preprocess_data(train_professional, test_professional, professional_features, 'Depression')
    professional_predictions = train_and_predict(X_train_professional, y_train_professional, X_test_professional, 'Professional')

    # Add predictions to respective test datasets
    test_student['Depression_Predicted'] = student_predictions
    test_professional['Depression_Predicted'] = professional_predictions

    # Combine the results
    test_combined = pd.concat([test_student, test_professional], ignore_index=True)

    # Output only 'id' and 'Depression_Predicted'
    output_file = 'test_new_with_predictions.csv'
    output_df = test_combined[['id', 'Depression_Predicted']]
    output_df.to_csv(output_file, index=False)

    # Display the first few rows of the output
    print(output_df.head())
# Out:
# Validation Accuracy (Student): 0.87
# Validation Accuracy (Professional): 0.97
#        id  Depression_Predicted
# 0  140703                     1
# 1  140708                     0
# 2  140719                     1
# 3  140720                     1
# 4  140721                     1

# %% [markdown]
# finding: the validation accuracy for professionals is much higher than the validation accuracy for students<br>
# optional step: some important features to explain the target for professional may not work for students

# %% [markdown]
# ## Try to build meaningful models

# %% [markdown]
# ### Analyze the impact of each feature on target

# %%
import pandas as pd
import numpy as np
from scipy.stats import mannwhitneyu, chi2_contingency, fisher_exact
import warnings

# Ignore warnings for clean output
warnings.filterwarnings('ignore')

def analyze_numerical_feature(data, feature, target):
    """
    Performs Mann-Whitney U test on a numerical feature to compare distributions between target groups.
    """
    group0 = data[data[target] == 0][feature]
    group1 = data[data[target] == 1][feature]
    
    # Perform Mann-Whitney U Test
    stat, p = mannwhitneyu(group0, group1, alternative='two-sided')
    print(f"{feature}:\n\tMann-Whitney U Test p-value = {p:.5f}")
    
    # Interpretation
    group0_mean = group0.mean()
    group1_mean = group1.mean()
    print(f"\tMean for target=0: {group0_mean:.3f}, Mean for target=1: {group1_mean:.3f}")
    return p

def analyze_categorical_feature(data, feature, target):
    """
    Analyzes categorical features using Fisher's Exact Test for binary features and Chi-Squared Test for multi-category features.
    Also provides percentage distributions by category.
    """
    contingency_table = pd.crosstab(data[feature], data[target])
    print(f"\nContingency Table for {feature}:\n{contingency_table}")
    
    if contingency_table.shape == (2, 2):
        # Binary feature: Perform Fisher's Exact Test and calculate Odds Ratio
        odds_ratio, p = fisher_exact(contingency_table)
        print(f"\tFisher's Exact Test p-value = {p:.5f}, Odds Ratio = {odds_ratio:.3f}")
        
        # Interpretation of Odds Ratio
        category_names = contingency_table.index.tolist()
        if odds_ratio > 1:
            print(f"\t{category_names[1]} is {odds_ratio:.3f} times more likely to have {target}=1 than {category_names[0]}.")
        elif odds_ratio < 1:
            print(f"\t{category_names[1]} is {1/odds_ratio:.3f} times less likely to have {target}=1 than {category_names[0]}.")
        else:
            print(f"\t{category_names[1]} and {category_names[0]} are equally likely to have {target}=1.")
        return p
    else:
        # Multi-category feature: Perform Chi-Squared Test
        chi2, p, dof, expected = chi2_contingency(contingency_table)
        print(f"\tChi-Squared Test p-value = {p:.5f}, Chi2 Statistic = {chi2:.3f}, DOF = {dof}")
        
        # Interpretation of Chi-Squared Test
        if p < 0.05:
            print(f"\tThe distribution of {target} is significantly different across categories of {feature}.")
        else:
            print(f"\tThe distribution of {target} is not significantly different across categories of {feature}.")
        
        # Percentage Distribution for each category
        percentages = (contingency_table.div(contingency_table.sum(axis=1), axis=0) * 100).round(2)
        print("\nPercentage Distribution by Category (rounded to two decimal places):")
        print(percentages)
        
        # Highlight the category with the highest target=1 percentage
        if 1 in percentages.columns:
            highest_category = percentages[1].idxmax()
            print(f"\tCategory with the highest {target}=1 percentage: {highest_category} ({percentages[1].max():.2f}%)")
        return p

def perform_statistical_analysis(data, features, target):
    """
    Performs statistical analysis on a dataset, evaluating the impact of numerical and categorical features on the target.
    """
    print(f"\n=== Statistical Analysis for Dataset ===\n")
    
    # Separate numerical and categorical features
    numerical_features = data[features].select_dtypes(include=['int64', 'float64']).columns.tolist()
    categorical_features = [col for col in features if col not in numerical_features]
    
    significant_numerical_features = []
    significant_categorical_features = []
    
    alpha = 0.05  # Significance level
    
    # Analyze numerical features
    print("\nNumerical Features Analysis:")
    for feature in numerical_features:
        p_value = analyze_numerical_feature(data, feature, target)
        if p_value < alpha:
            significant_numerical_features.append(feature)
    
    # Analyze categorical features
    print("\nCategorical Features Analysis:")
    for feature in categorical_features:
        p_value = analyze_categorical_feature(data, feature, target)
        if p_value is not None and p_value < alpha:
            significant_categorical_features.append(feature)
    
    print("\nSignificant Numerical Features:", significant_numerical_features)
    print("Significant Categorical Features:", significant_categorical_features)
    return significant_numerical_features, significant_categorical_features

# Main execution
if __name__ == "__main__":
    # Real Features for Students
    student_features = [
        'Gender', 'Age', 'city_type', 'Academic Pressure', 'CGPA', 'Study Satisfaction',
        'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?',
        'Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness'
    ]
    
    # Real Features for Professionals
    professional_features = [
        'Gender', 'Age', 'city_type', 'Profession', 'Work Pressure', 'Job Satisfaction',
        'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?',
        'Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness'
    ]
    
    target = 'Depression'
    
    print("\n=== Statistical Analysis for train_student ===")
    significant_numerical_features_student, significant_categorical_features_student = perform_statistical_analysis(
        train_student, student_features, target
    )
    
    print("\n=== Statistical Analysis for train_professional ===")
    significant_numerical_features_prof, significant_categorical_features_prof = perform_statistical_analysis(
        train_professional, professional_features, target
    )
# Out:
# === Statistical Analysis for train_student ===
#
# === Statistical Analysis for Dataset ===
#
#
# Numerical Features Analysis:
# Age:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 27.232, Mean for target=1: 24.919
# Academic Pressure:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 2.364, Mean for target=1: 3.681
# CGPA:
# 	Mann-Whitney U Test p-value = 0.00002
# 	Mean for target=0: 7.632, Mean for target=1: 7.704
# Study Satisfaction:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 3.224, Mean for target=1: 2.761
# Work/Study Hours:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 6.221, Mean for target=1: 7.773
# Financial Stress:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 2.523, Mean for target=1: 3.586
#
# Categorical Features Analysis:
#
# Contingency Table for Gender:
# Depression     0      1
# Gender
# Female      6109   8647
# Male        7736  10479
# 	Fisher's Exact Test p-value = 0.05090, Odds Ratio = 0.957
# 	Male is 1.045 times less likely to have Depression=1 than Female.
#
# Contingency Table for city_type:
# Depression     0      1
# city_type
# big         6221   8936
# small       7624  10190
# 	Fisher's Exact Test p-value = 0.00131, Odds Ratio = 0.930
# 	small is 1.075 times less likely to have Depression=1 than big.
#
# Contingency Table for Sleep Duration:
# Depression            0     1
# Sleep Duration
# 5-6 hours          3169  4134
# 7-8 hours          3617  5111
# Less than 5 hours  3499  6298
# More than 8 hours  3560  3583
# 	Chi-Squared Test p-value = 0.00000, Chi2 Statistic = 346.006, DOF = 3
# 	The distribution of Depression is significantly different across categories of Sleep Duration.
#
# Percentage Distribution by Category (rounded to two decimal places):
# Depression             0      1
# Sleep Duration
# 5-6 hours          43.39  56.61
# 7-8 hours          41.44  58.56
# Less than 5 hours  35.72  64.28
# More than 8 hours  49.84  50.16
# 	Category with the highest Depression=1 percentage: Less than 5 hours (64.28%)
#
# Contingency Table for Dietary Habits:
# Depression         0     1
# Dietary Habits
# Healthy         4979  4003
# Moderate        5182  6497
# Unhealthy       3684  8626
# 	Chi-Squared Test p-value = 0.00000, Chi2 Statistic = 1428.939, DOF = 2
# 	The distribution of Depression is significantly different across categories of Dietary Habits.
#
# Percentage Distribution by Category (rounded to two decimal places):
# Depression          0      1
# Dietary Habits
# Healthy         55.43  44.57
# Moderate        44.37  55.63
# Unhealthy       29.93  70.07
# 	Category with the highest Depression=1 percentage: Unhealthy (70.07%)
#
# Contingency Table for Degree:
# Depression     0     1
# Degree
# B.Arch       720  1002
# B.Com        767   999
# B.Ed        1022  1228
# B.Pharm      482   506
# B.Tech       591   761
# BA           305   383
# BBA          331   478
# BCA          723   925
# BE           406   476
# BHM          521   670
# BSc          435   595
# Class 12    2042  4958
# LLB          401   435
# LLM          276   286
# M.Com        375   437
# M.Ed         493   482
# M.Pharm      329   372
# M.Tech       592   608
# MA           323   369
# MBA          309   333
# MBBS         328   431
# MCA          579   670
# MD           342   364
# ME           106   113
# MHM          113   117
# MSc          633   797
# PhD          301   331
# 	Chi-Squared Test p-value = 0.00000, Chi2 Statistic = 667.879, DOF = 26
# 	The distribution of Depression is significantly different across categories of Degree.
#
# Percentage Distribution by Category (rounded to two decimal places):
# Depression      0      1
# Degree
# B.Arch      41.81  58.19
# B.Com       43.43  56.57
# B.Ed        45.42  54.58
# B.Pharm     48.79  51.21
# B.Tech      43.71  56.29
# BA          44.33  55.67
# BBA         40.91  59.09
# BCA         43.87  56.13
# BE          46.03  53.97
# BHM         43.74  56.26
# BSc         42.23  57.77
# Class 12    29.17  70.83
# LLB         47.97  52.03
# LLM         49.11  50.89
# M.Com       46.18  53.82
# M.Ed        50.56  49.44
# M.Pharm     46.93  53.07
# M.Tech      49.33  50.67
# MA          46.68  53.32
# MBA         48.13  51.87
# MBBS        43.21  56.79
# MCA         46.36  53.64
# MD          48.44  51.56
# ME          48.40  51.60
# MHM         49.13  50.87
# MSc         44.27  55.73
# PhD         47.63  52.37
# 	Category with the highest Depression=1 percentage: Class 12 (70.83%)
#
# Contingency Table for Have you ever had suicidal thoughts ?:
# Depression                                0      1
# Have you ever had suicidal thoughts ?
# No                                     9385   2758
# Yes                                    4460  16368
# 	Fisher's Exact Test p-value = 0.00000, Odds Ratio = 12.488
# 	Yes is 12.488 times more likely to have Depression=1 than No.
#
# Contingency Table for Family History of Mental Illness:
# Depression                           0     1
# Family History of Mental Illness
# No                                7524  9488
# Yes                               6321  9638
# 	Fisher's Exact Test p-value = 0.00000, Odds Ratio = 1.209
# 	Yes is 1.209 times more likely to have Depression=1 than No.
#
# Significant Numerical Features: ['Age', 'Academic Pressure', 'CGPA', 'Study Satisfaction', 'Work/Study Hours', 'Financial Stress']
# Significant Categorical Features: ['city_type', 'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']
#
# === Statistical Analysis for train_professional ===
#
# === Statistical Analysis for Dataset ===
#
#
# Numerical Features Analysis:
# Age:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 45.504, Mean for target=1: 26.771
# Work Pressure:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 2.910, Mean for target=1: 4.014
# Job Satisfaction:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 3.048, Mean for target=1: 2.173
# Work/Study Hours:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 5.883, Mean for target=1: 7.861
# Financial Stress:
# 	Mann-Whitney U Test p-value = 0.00000
# 	Mean for target=0: 2.876, Mean for target=1: 3.843
#
# Categorical Features Analysis:
#
# Contingency Table for Gender:
# Depression      0     1
# Gender
# Female      53012  4655
# Male        63547  5732
# 	Fisher's Exact Test p-value = 0.19510, Odds Ratio = 1.027
# 	Male is 1.027 times more likely to have Depression=1 than Female.
#
# Contingency Table for city_type:
# Depression      0     1
# city_type
# big         57690  5171
# small       58869  5216
# 	Fisher's Exact Test p-value = 0.57330, Odds Ratio = 0.989
# 	small is 1.012 times less likely to have Depression=1 than big.
#
# Contingency Table for Profession:
# Depression                  0     1
# Profession
# Accountant               1366    95
# Architect                4440   471
# Business Analyst         3296   189
# Chef                     3171   159
# Chemist                  3169    94
# Civil Engineer           1504   133
# Consultant               4462   216
# Content Writer           8674   161
# Customer Support         2192   111
# Data Scientist           2426   206
# Digital Marketer         1435    65
# Doctor                   3371   179
# Educational Consultant   2943   230
# Electrician              1649    73
# Entrepreneur             3284    71
# Finanancial Analyst      1422    58
# Financial Analyst        1584   143
# Graphic Designer         1084   245
# HR Manager               4074   485
# Investment Banker         388    32
# Judge                    1665   207
# Lawyer                   2383   208
# Manager                  1780   159
# Marketing Manager        2119   103
# Mechanical Engineer      1167   128
# Pharmacist               4278   107
# Pilot                    2080   108
# Plumber                  1810   127
# Research Analyst          705    43
# Researcher               2539   115
# Sales Executive          1835    86
# Software Engineer        1530    97
# Teacher                 33250  5312
# Travel Consultant        1957   105
# UX/UI Designer           1527    66
# 	Chi-Squared Test p-value = 0.00000, Chi2 Statistic = 3418.891, DOF = 34
# 	The distribution of Depression is significantly different across categories of Profession.
#
# Percentage Distribution by Category (rounded to two decimal places):
# Depression                  0      1
# Profession
# Accountant              93.50   6.50
# Architect               90.41   9.59
# Business Analyst        94.58   5.42
# Chef                    95.23   4.77
# Chemist                 97.12   2.88
# Civil Engineer          91.88   8.12
# Consultant              95.38   4.62
# Content Writer          98.18   1.82
# Customer Support        95.18   4.82
# Data Scientist          92.17   7.83
# Digital Marketer        95.67   4.33
# Doctor                  94.96   5.04
# Educational Consultant  92.75   7.25
# Electrician             95.76   4.24
# Entrepreneur            97.88   2.12
# Finanancial Analyst     96.08   3.92
# Financial Analyst       91.72   8.28
# Graphic Designer        81.57  18.43
# HR Manager              89.36  10.64
# Investment Banker       92.38   7.62
# Judge                   88.94  11.06
# Lawyer                  91.97   8.03
# Manager                 91.80   8.20
# Marketing Manager       95.36   4.64
# Mechanical Engineer     90.12   9.88
# Pharmacist              97.56   2.44
# Pilot                   95.06   4.94
# Plumber                 93.44   6.56
# Research Analyst        94.25   5.75
# Researcher              95.67   4.33
# Sales Executive         95.52   4.48
# Software Engineer       94.04   5.96
# Teacher                 86.22  13.78
# Travel Consultant       94.91   5.09
# UX/UI Designer          95.86   4.14
# 	Category with the highest Depression=1 percentage: Graphic Designer (18.43%)
#
# Contingency Table for Sleep Duration:
# Depression             0     1
# Sleep Duration
# 5-6 hours          27252  1987
# 7-8 hours          31095  2532
# Less than 5 hours  29984  4219
# More than 8 hours  28228  1649
# 	Chi-Squared Test p-value = 0.00000, Chi2 Statistic = 1161.084, DOF = 3
# 	The distribution of Depression is significantly different across categories of Sleep Duration.
#
# Percentage Distribution by Category (rounded to two decimal places):
# Depression             0      1
# Sleep Duration
# 5-6 hours          93.20   6.80
# 7-8 hours          92.47   7.53
# Less than 5 hours  87.66  12.34
# More than 8 hours  94.48   5.52
# 	Category with the highest Depression=1 percentage: Less than 5 hours (12.34%)
#
# Contingency Table for Dietary Habits:
# Depression          0     1
# Dietary Habits
# Healthy         39500  2042
# Moderate        41611  2971
# Unhealthy       35448  5374
# 	Chi-Squared Test p-value = 0.00000, Chi2 Statistic = 2075.641, DOF = 2
# 	The distribution of Depression is significantly different across categories of Dietary Habits.
#
# Percentage Distribution by Category (rounded to two decimal places):
# Depression          0      1
# Dietary Habits
# Healthy         95.08   4.92
# Moderate        93.34   6.66
# Unhealthy       86.84  13.16
# 	Category with the highest Depression=1 percentage: Unhealthy (13.16%)
#
# Contingency Table for Degree:
# Depression      0     1
# Degree
# B.Arch       7710   570
# B.Com        6835   450
# B.Ed        10465   550
# B.Pharm      5358   291
# B.Tech       3336   339
# BA           3346   172
# BBA          4496   288
# BCA          4309   384
# BE           2563   284
# BHM          3706   278
# BSc          4285   269
# Class 12     5914  3634
# LLB          4031   367
# LLM          4504   341
# M.Com        2555   114
# M.Ed         5609   149
# M.Pharm      4309   161
# M.Tech       3801   153
# MA           2366   246
# MBA          3486   180
# MBBS         2473   127
# MCA          4473   238
# MD           3144   114
# ME           3549   176
# MHM          3224   142
# MSc          3980   181
# PhD          2732   189
# 	Chi-Squared Test p-value = 0.00000, Chi2 Statistic = 12757.963, DOF = 26
# 	The distribution of Depression is significantly different across categories of Degree.
#
# Percentage Distribution by Category (rounded to two decimal places):
# Depression      0      1
# Degree
# B.Arch      93.12   6.88
# B.Com       93.82   6.18
# B.Ed        95.01   4.99
# B.Pharm     94.85   5.15
# B.Tech      90.78   9.22
# BA          95.11   4.89
# BBA         93.98   6.02
# BCA         91.82   8.18
# BE          90.02   9.98
# BHM         93.02   6.98
# BSc         94.09   5.91
# Class 12    61.94  38.06
# LLB         91.66   8.34
# LLM         92.96   7.04
# M.Com       95.73   4.27
# M.Ed        97.41   2.59
# M.Pharm     96.40   3.60
# M.Tech      96.13   3.87
# MA          90.58   9.42
# MBA         95.09   4.91
# MBBS        95.12   4.88
# MCA         94.95   5.05
# MD          96.50   3.50
# ME          95.28   4.72
# MHM         95.78   4.22
# MSc         95.65   4.35
# PhD         93.53   6.47
# 	Category with the highest Depression=1 percentage: Class 12 (38.06%)
#
# Contingency Table for Have you ever had suicidal thoughts ?:
# Depression                                 0     1
# Have you ever had suicidal thoughts ?
# No                                     67065  1221
# Yes                                    49494  9166
# 	Fisher's Exact Test p-value = 0.00000, Odds Ratio = 10.172
# 	Yes is 10.172 times more likely to have Depression=1 than No.
#
# Contingency Table for Family History of Mental Illness:
# Depression                            0     1
# Family History of Mental Illness
# No                                58162  4861
# Yes                               58397  5526
# 	Fisher's Exact Test p-value = 0.00000, Odds Ratio = 1.132
# 	Yes is 1.132 times more likely to have Depression=1 than No.
#
# Significant Numerical Features: ['Age', 'Work Pressure', 'Job Satisfaction', 'Work/Study Hours', 'Financial Stress']
# Significant Categorical Features: ['Profession', 'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']

# %% [markdown]
# Todo: check the meaning of class = 12 <br>
#
# Findings:<br>
# Observations:<br>
# Persona:<br>
# Suggestions:<br>
